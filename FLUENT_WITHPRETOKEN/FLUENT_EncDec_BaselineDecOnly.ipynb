# %%
# !nvidia-smi
# Out:
# Tue Oct  8 15:56:12 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:47:00.0 Off |                    0 |
# | N/A   40C    P0   233W / 400W |  73737MiB / 81251MiB |     99%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from transformers import AutoTokenizer, AutoModel, GPT2LMHeadModel, GPT2Tokenizer
from sklearn.decomposition import PCA
from torch import nn
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import torch
import matplotlib.pyplot as plt
import time
import pandas as pd

# %%
# knowledgebase_url = 'https://github.com/AndiAlifs/FLUENT-Chatbot-2023/raw/main/KnowledgeBaseFilkom.xlsx'
knowledgebase_url = 'https://github.com/AndiAlifs/FLUENT-Chatbot-2023/raw/main/KnowledgeBaseFilkom_simple.xlsx'
knowledgebase = pd.read_excel(knowledgebase_url)

qa_paired = knowledgebase.drop(columns=knowledgebase.columns.drop(['Pertanyaan', 'Jawaban']))
qa_paired.dropna(inplace=True)
qa_paired
# Out:
#                                            Pertanyaan  \
# 0                                         visi filkom
# 1                                         misi filkom
# 2                                  apa tujuan filkom?
# 3                           sasaran pendidikan filkom
# 4                             email fitra a. bachtiar
# 5                 bidang penelitian fitra a. bachtiar
# 6                              tanggal dibentuk ptiik
# 7                           sasaran pengabdian filkom
# 8                            sasaran kerjasama filkom
# 9                 dekan fakultas ilmu komputer filkom
# 10        wakil dekan bidang akademik / wakil dekan 1
# 11  wakil dekan bidang umum, keuangan, dan sumber ...
# 12  wakil dekan bidang kemahasiswaan, alumni, dan ...
# 13                ketua departemen teknik informatika
# 14           sekretaris departemen teknik informatika
# 15         ketua program studi magister ilmu komputer
# 16     ketua program studi sarjana teknik informatika
# 17        ketua program studi sarjana teknik komputer
# 18                  ketua departemen sistem informasi
# 19              seketaris departemen sistem informasi
# 20       ketua program studi sarjana sistem informasi
# 21  ketua program studi sarjana pendidikan teknolo...
# 22    ketua program studi sarjana teknologi informasi
# 23                      berikan saya informasi alumni
# 24         apa saja layanan kemahasiswaan filkom ub ?
# 25  bagaimana pengajuan proposal dan lpj kegiatan ...
# 26          berikan informasi dokumen kemahasiswaan ?
# 27  bagaimana pengajuan surat tugas dosen pembimbi...
# 28           bagaimana permohonan validasi data skm ?
# 29  berikan informasi mengenai validasi syarat wisuda
# 30        bagaimana mengakses tracer study fakultas ?
# 31          bagaimana cara pendaftaran wisuda ulang ?
# 32  berikan informasi mengenai layanan bimbingan d...
# 33  berikan informasi mengenai layanan ultksp (uni...
# 34  berikan informasi mengenai tracking layanan ke...
# 35  berikan informasi mengenai bimbingan dan konse...
# 36                        apa tujuan unit konseling ?
# 37  apa fungsi bimbingan dan konseling serta penas...
# 38          apa saja program layanan unit konseling ?
# 39                     apa manfaat konseling filkom ?
# 40       berikan informasi mengenai layanan konseling
# 41  siapa konselor bimbingan dan konseling di filk...
# 42                siapa koordinator konselor sebaya ?
# 43                     berikan rincian layanan ultksp
#
#                                               Jawaban
# 0   menjadi fakultas yang berdaya saing internasio...
# 1   menyelenggarakan pendidikan di bidang teknolog...
# 2   menghasilkan lulusan yang kompeten , profesion...
# 3   meningkatkan kompetensi dan kualifikasi pendid...
# 4                          fitra.bachtiar[at]ub.ac.id
# 5   affective computing, affective engineering, in...
# 6                                     27 oktober 2011
# 7   1. meningkatkan kualitas dan kuantitas pengabd...
# 8   1. mengadakan kerjasama pendidikan, penlitian ...
# 9   prof. ir. wayan firdaus mahmudy, s.si., mt., p...
# 10                dr. eng. ir. herman tolle, st., mt.
# 11                      agus wahyu widodo, st., m.cs.
# 12                      drs. muh. arif rahman, m.kom.
# 13                  achmad basuki, s.t., m.mg., ph.d.
# 14               ir. primantara hari trisnawan, m.sc.
# 15      sabriansyah rizqika akbar, s.t., m.eng., ph.d
# 16                   adhitya bhawiyuga, s.kom., m.sc.
# 17       barlian henryranu prasetio, s.t., m.t., ph.d
# 18                         issa arwani, s.kom., m.sc.
# 19              satrio agung wicaksono, s.kom., m.kom
# 20                 yusi tyroni mursityo, s.kom., m.s.
# 21            ir. admaja dwi herlambang, s.pd., m.pd.
# 22  ir. widhy hayuhardhika nugraha putra, s.kom., ...
# 23  informasi alumni dapat diakses pada link berik...
# 24  1. pengajuan proposal dan lpj kegiatan kemahas...
# 25  pengajuan proposal kegiatan kemahasiswaan\npen...
# 26  informasi dokumen kemahasiswaan dapat dilihat ...
# 27  informasi pengajuan surat tugas dosen pembimbi...
# 28  permohonan validasi data skm dapat dilihat pad...
# 29  1. unggah dokumen di siam\n2. mengisi gform pe...
# 30  tracer study fakultas dapat diakses pada tauta...
# 31  pendaftaran wisuda ulang dapat diakses pada ta...
# 32  layanan bimbingan dan konseling dapat diaksesp...
# 33  layanan ultksp dapat diaksespada tautan beriku...
# 34  tracking layanan kemahasiswaan dapat diaksespa...
# 35  dalam perjalanannya menuntut ilmu, mahasiswa t...
# 36  1. mewujudkan potensi dirinya secara optimal, ...
# 37  1. penyaluran: bimbingan berfungsi dalam memba...
# 38  1. pelayanan bantuan pemecahan masalah, baik y...
# 39  1. masalah ditangani oleh ahli yang kompeten d...
# 40  informasi mengenai layanan konseling dapat dia...
# 41  ada 2 konselor bimbingan dan konseling di filk...
# 42  koordinator konselor sebaya adalah muhammad da...
# 43  rincian layanan ultksp dapat diakses pada taut...

# %%
knowledgebase_eval_url = 'https://github.com/AndiAlifs/FLUENT-Chatbot-2023/raw/main/KnowledgeBaseFilkom_eval.xlsx'
knowledgebase_eval = pd.read_excel(knowledgebase_eval_url)

qa_paired_eval = knowledgebase_eval.drop(columns=knowledgebase_eval.columns.drop(['Pertanyaan', 'Jawaban']))
qa_paired_eval.dropna(inplace=True)
qa_paired_eval
# Out:
#                                           Pertanyaan  \
# 0                                  apa visi fakultas
# 1                                  visi dari filkokm
# 2                               apa saja visi filkom
# 3                                  apa misi fakultas
# 4                                apa saja misi flkom
# ..                                               ...
# 69                      apa manfaat konseling filkom
# 70      berikan informasi mengenai layanan konseling
# 71  siapa konselor bimbingan dan konseling di filkom
# 72                 siapa koordinator konselor sebaya
# 73                    berikan rincian layanan ultksp
#
#                                               Jawaban
# 0   menjadi fakultas yang berdaya saing internasio...
# 1   menjadi fakultas yang berdaya saing internasio...
# 2   menjadi fakultas yang berdaya saing internasio...
# 3   menyelenggarakan pendidikan di bidang teknolog...
# 4   menyelenggarakan pendidikan di bidang teknolog...
# ..                                                ...
# 69  1. masalah ditangani oleh ahli yang kompeten d...
# 70  informasi mengenai layanan konseling dapat dia...
# 71  ada 2 konselor bimbingan dan konseling di filk...
# 72  koordinator konselor sebaya adalah muhammad da...
# 73  rincian layanan ultksp dapat diakses pada taut...
#
# [74 rows x 2 columns]

# %%
enc_tokenizer = AutoTokenizer.from_pretrained('firqaaa/indo-sentence-bert-base')
enc_model = AutoModel.from_pretrained('firqaaa/indo-sentence-bert-base')
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# model_name_dec = 'flax-community/gpt2-medium-indonesian'
model_name_dec = 'indonesian-nlp/gpt2-medium-indonesian'

dec_model = GPT2LMHeadModel.from_pretrained(model_name_dec)
dec_tokenizer = GPT2Tokenizer.from_pretrained(model_name_dec)

dec_tokenizer.add_tokens(['[PRE1]'])
dec_tokenizer.add_tokens(['[PRE2]'])
dec_tokenizer.add_tokens(['[PRE3]'])
dec_tokenizer.add_tokens(['[PRE4]'])
dec_tokenizer.add_tokens(['[PRE5]'])

dec_tokenizer.add_special_tokens({'pad_token': '[PAD]',
                                    'bos_token': '[BOS]',
                                    'eos_token': '[EOS]',
                                    'sep_token': '[SEP]',})

# Add a new token to the tokenizer
dec_model.config.pad_token_id = dec_tokenizer.pad_token_id
dec_model.config.bos_token_id = dec_tokenizer.bos_token_id
dec_model.config.eos_token_id = dec_tokenizer.eos_token_id
dec_model.config.sep_token_id = dec_tokenizer.sep_token_id

dec_model.resize_token_embeddings(len(dec_tokenizer))
# Out:
# Embedding(50266, 1024)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
enc_model = enc_model.to(device)
dec_model = dec_model.to(device)

# %%
qa_paired_test = qa_paired
qa_paired_test = qa_paired_test.applymap(lambda x: x.lower() if isinstance(x, str) else x)
qa_paired_test['Jawaban'] = qa_paired_test['Jawaban'].apply(lambda x: '[BOS]' + x + '[EOS]')
qa_paired_test = qa_paired_test.reset_index(drop=True)
qa_paired_test
# Out:
#                                            Pertanyaan  \
# 0                                         visi filkom
# 1                                         misi filkom
# 2                                  apa tujuan filkom?
# 3                           sasaran pendidikan filkom
# 4                             email fitra a. bachtiar
# 5                 bidang penelitian fitra a. bachtiar
# 6                              tanggal dibentuk ptiik
# 7                           sasaran pengabdian filkom
# 8                            sasaran kerjasama filkom
# 9                 dekan fakultas ilmu komputer filkom
# 10        wakil dekan bidang akademik / wakil dekan 1
# 11  wakil dekan bidang umum, keuangan, dan sumber ...
# 12  wakil dekan bidang kemahasiswaan, alumni, dan ...
# 13                ketua departemen teknik informatika
# 14           sekretaris departemen teknik informatika
# 15         ketua program studi magister ilmu komputer
# 16     ketua program studi sarjana teknik informatika
# 17        ketua program studi sarjana teknik komputer
# 18                  ketua departemen sistem informasi
# 19              seketaris departemen sistem informasi
# 20       ketua program studi sarjana sistem informasi
# 21  ketua program studi sarjana pendidikan teknolo...
# 22    ketua program studi sarjana teknologi informasi
# 23                      berikan saya informasi alumni
# 24         apa saja layanan kemahasiswaan filkom ub ?
# 25  bagaimana pengajuan proposal dan lpj kegiatan ...
# 26          berikan informasi dokumen kemahasiswaan ?
# 27  bagaimana pengajuan surat tugas dosen pembimbi...
# 28           bagaimana permohonan validasi data skm ?
# 29  berikan informasi mengenai validasi syarat wisuda
# 30        bagaimana mengakses tracer study fakultas ?
# 31          bagaimana cara pendaftaran wisuda ulang ?
# 32  berikan informasi mengenai layanan bimbingan d...
# 33  berikan informasi mengenai layanan ultksp (uni...
# 34  berikan informasi mengenai tracking layanan ke...
# 35  berikan informasi mengenai bimbingan dan konse...
# 36                        apa tujuan unit konseling ?
# 37  apa fungsi bimbingan dan konseling serta penas...
# 38          apa saja program layanan unit konseling ?
# 39                     apa manfaat konseling filkom ?
# 40       berikan informasi mengenai layanan konseling
# 41  siapa konselor bimbingan dan konseling di filk...
# 42                siapa koordinator konselor sebaya ?
# 43                     berikan rincian layanan ultksp
#
#                                               Jawaban
# 0   [BOS]menjadi fakultas yang berdaya saing inter...
# 1   [BOS]menyelenggarakan pendidikan di bidang tek...
# 2   [BOS]menghasilkan lulusan yang kompeten , prof...
# 3   [BOS]meningkatkan kompetensi dan kualifikasi p...
# 4               [BOS] fitra.bachtiar[at]ub.ac.id[EOS]
# 5   [BOS]affective computing, affective engineerin...
# 6                           [BOS]27 oktober 2011[EOS]
# 7   [BOS]1. meningkatkan kualitas dan kuantitas pe...
# 8   [BOS]1. mengadakan kerjasama pendidikan, penli...
# 9   [BOS]prof. ir. wayan firdaus mahmudy, s.si., m...
# 10      [BOS]dr. eng. ir. herman tolle, st., mt.[EOS]
# 11            [BOS]agus wahyu widodo, st., m.cs.[EOS]
# 12            [BOS]drs. muh. arif rahman, m.kom.[EOS]
# 13        [BOS]achmad basuki, s.t., m.mg., ph.d.[EOS]
# 14     [BOS]ir. primantara hari trisnawan, m.sc.[EOS]
# 15  [BOS]sabriansyah rizqika akbar, s.t., m.eng., ...
# 16         [BOS]adhitya bhawiyuga, s.kom., m.sc.[EOS]
# 17  [BOS]barlian henryranu prasetio, s.t., m.t., p...
# 18               [BOS]issa arwani, s.kom., m.sc.[EOS]
# 19    [BOS]satrio agung wicaksono, s.kom., m.kom[EOS]
# 20       [BOS]yusi tyroni mursityo, s.kom., m.s.[EOS]
# 21  [BOS]ir. admaja dwi herlambang, s.pd., m.pd.[EOS]
# 22  [BOS]ir. widhy hayuhardhika nugraha putra, s.k...
# 23  [BOS]informasi alumni dapat diakses pada link ...
# 24  [BOS]1. pengajuan proposal dan lpj kegiatan ke...
# 25  [BOS]pengajuan proposal kegiatan kemahasiswaan...
# 26  [BOS]informasi dokumen kemahasiswaan dapat dil...
# 27  [BOS]informasi pengajuan surat tugas dosen pem...
# 28  [BOS]permohonan validasi data skm dapat diliha...
# 29  [BOS]1. unggah dokumen di siam\n2. mengisi gfo...
# 30  [BOS]tracer study fakultas dapat diakses pada ...
# 31  [BOS]pendaftaran wisuda ulang dapat diakses pa...
# 32  [BOS]layanan bimbingan dan konseling dapat dia...
# 33  [BOS]layanan ultksp dapat diaksespada tautan b...
# 34  [BOS]tracking layanan kemahasiswaan dapat diak...
# 35  [BOS]dalam perjalanannya menuntut ilmu, mahasi...
# 36  [BOS]1. mewujudkan potensi dirinya secara opti...
# 37  [BOS]1. penyaluran: bimbingan berfungsi dalam ...
# 38  [BOS]1. pelayanan bantuan pemecahan masalah, b...
# 39  [BOS]1. masalah ditangani oleh ahli yang kompe...
# 40  [BOS]informasi mengenai layanan konseling dapa...
# 41  [BOS]ada 2 konselor bimbingan dan konseling di...
# 42  [BOS]koordinator konselor sebaya adalah muhamm...
# 43  [BOS]rincian layanan ultksp dapat diakses pada...

# %%
class FLUENTSOTA(nn.Module):
    def __init__(self, enc_model, dec_model, enc_tokenizer, dec_tokenizer, max_length=200):
        super(FLUENTSOTA, self).__init__()
        self.enc_model = enc_model
        self.dec_model = dec_model
        self.enc_tokenizer = enc_tokenizer
        self.dec_tokenizer = dec_tokenizer
        self.enc_mapper = nn.Linear(768, 1024)
        self.enc_mapper2 = nn.Linear(1024, 1024)
        self.prefix_nn = nn.Linear(1024, 1024)
        self.prefix_nn2 = nn.Linear(1024, 1024)
        self.prefix_nn3 = nn.Linear(1024, 1024)
        self.prefix_nn4 = nn.Linear(1024, 1024)
        self.prefix_nn5 = nn.Linear(1024, 1024)
        self.max_length = max_length
    
    def encoding(self, sentence):
        tokens = self.enc_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        tokens = tokens.to(device)
        with torch.no_grad():
            output = self.enc_model(**tokens)
        enc_logits = output.last_hidden_state.mean(dim=1)
        enc_logits = self.enc_mapper(enc_logits).to(device)
        enc_logits = self.enc_mapper2(enc_logits).to(device)
        return enc_logits

    def get_embedding(self, sentence):
        tokens = self.dec_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        tokens = tokens.to(device)
        wte = self.dec_model.get_input_embeddings()
        return wte(tokens['input_ids'])

    def dec_tokenizer(self, sentence):
        tokens = self.dec_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        return tokens

    def add_prefix(self, enc_logits):
        prefix_1 = self.prefix_nn(enc_logits)
        prefix_2 = self.prefix_nn2(enc_logits)
        prefix_3 = self.prefix_nn3(enc_logits)
        prefix_4 = self.prefix_nn4(enc_logits)
        prefix_5 = self.prefix_nn5(enc_logits)

        prefixs = torch.stack((prefix_1, prefix_2, prefix_3, prefix_4, prefix_5), dim=1)
        return prefixs

    def decoding_train(self, enc_logits, target, target_with_pre):
        prefixs = self.add_prefix(enc_logits)
        embed = self.get_embedding(target)
        pref_with_embed = torch.cat((prefixs, embed), dim=1)
        output = self.dec_model(inputs_embeds=pref_with_embed, labels=target_with_pre)
        return output

    def generate(self, quest):
        enc_logits = self.encoding(quest)
        prefix_se = '[BOS]'
        prefix_dec_embed = self.get_embedding(prefix_se)
        prefixs = self.add_prefix(enc_logits)
        
        pref_with_embed = torch.cat((prefixs, prefix_dec_embed), dim=1)

        output = self.dec_model.generate(   inputs_embeds=pref_with_embed, 
                                            max_length=self.max_length, 
                                            pad_token_id=self.dec_model.config.eos_token_id)
        returned_output = []
        for i in range(len(output[0])):
            if output[0][i] != self.dec_model.config.eos_token_id:
                returned_output.append(output[0][i])
            else:
                break
        return torch.tensor(returned_output).unsqueeze(0)

# %%
for param in enc_model.parameters():
    param.requires_grad = False

for param in dec_model.parameters():
    param.requires_grad = False

for param in dec_model.transformer.h[:-15].parameters():
    param.requires_grad = True

for param in enc_model.encoder.layer[:-15].parameters():
    param.requires_grad = True

# %%
model = FLUENTSOTA(enc_model, dec_model, enc_tokenizer, dec_tokenizer)
model.to(device)
# Out:
# FLUENTSOTA(
#   (enc_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(50000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dec_model): GPT2LMHeadModel(
#     (transformer): GPT2Model(
#       (wte): Embedding(50266, 1024)
#       (wpe): Embedding(1024, 1024)
#       (drop): Dropout(p=0.0, inplace=False)
#       (h): ModuleList(
#         (0): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (9): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (10): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (11): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (12): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (13): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (14): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (15): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (16): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (17): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (18): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (19): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (20): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (21): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (22): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (23): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (lm_head): Linear(in_features=1024, out_features=50266, bias=False)
#   )
#   (enc_mapper): Linear(in_features=768, out_features=1024, bias=True)
#   (enc_mapper2): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn2): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn3): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn4): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn5): Linear(in_features=1024, out_features=1024, bias=True)
# )

# %%
all_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
untrainable_params = all_params - trainable_params

print(f'All parameters: {all_params:,}')
print(f'Trainable parameters: {trainable_params:,} ({trainable_params/all_params*100:.2f}%)')
print(f'Untrainable parameters: {untrainable_params:,} ({untrainable_params/all_params*100:.2f}%)')
# Out:
# All parameters: 486,358,784
# Trainable parameters: 120,451,072 (24.77%)
# Untrainable parameters: 365,907,712 (75.23%)

# %%
def calculate_bleu(preds, questions, answers):
    bleu_score_1 = 0
    bleu_score_2 = 0
    bleu_score_3 = 0
    bleu_score_4 = 0
    cum_bleu_score_1 = 0
    cum_bleu_score_2 = 0
    cum_bleu_score_3 = 0
    cum_bleu_score_4 = 0

    num_of_rows_calculated = 0
    smoothing_function = SmoothingFunction().method1

    for i, (question, real_answer) in enumerate(zip(questions, answers)):
        # print(f"Question: {question}")
        # print(f"Real Answer: {real_answer}")
        # print(f"Predicted Answer: {preds[i]}")
        refs = [real_answer.split(' ')]
        hyp = preds[i].split(' ')

        bleu_score_1 += sentence_bleu(refs, hyp, weights=(1,0,0,0), smoothing_function=smoothing_function)
        bleu_score_2 += sentence_bleu(refs, hyp, weights=(0,1,0,0), smoothing_function=smoothing_function)
        bleu_score_3 += sentence_bleu(refs, hyp, weights=(0,0,1,0), smoothing_function=smoothing_function)
        bleu_score_4 += sentence_bleu(refs, hyp, weights=(0,0,0,1), smoothing_function=smoothing_function)
        cum_bleu_score_1 += sentence_bleu(refs, hyp, weights=(1,0,0,0), smoothing_function=smoothing_function)
        cum_bleu_score_2 += sentence_bleu(refs, hyp, weights=(0.5,0.5,0,0), smoothing_function=smoothing_function)
        cum_bleu_score_3 += sentence_bleu(refs, hyp, weights=(0.33,0.33,0.33,0), smoothing_function=smoothing_function)
        cum_bleu_score_4 += sentence_bleu(refs, hyp, weights=(0.25,0.25,0.25,0.25), smoothing_function=smoothing_function)

        num_of_rows_calculated+=1

    results = {"1-gram": (bleu_score_1/num_of_rows_calculated),
                "2-gram": (bleu_score_2/num_of_rows_calculated),
                "3-gram": (bleu_score_3/num_of_rows_calculated),
                "4-gram": (bleu_score_4/num_of_rows_calculated),
                "cumulative-1-gram": (cum_bleu_score_1/num_of_rows_calculated),
                "cumulative-2-gram": (cum_bleu_score_2/num_of_rows_calculated),
                "cumulative-3-gram": (cum_bleu_score_3/num_of_rows_calculated),
                "cumulative-4-gram": (cum_bleu_score_4/num_of_rows_calculated)}

    return results

def count_bleu_score(model_count, real_answers, questions):
    preds = []
    for question in questions:
        outputs = model_count.generate(question)
        decoded_output = model_count.dec_tokenizer.decode(outputs[0])
        preds.append(decoded_output)
    return calculate_bleu(preds, questions, real_answers)

# %% [markdown]
# # Training

# %%
bleu_score = pd.DataFrame(columns=['Epoch', '1-gram', '2-gram', '3-gram', '4-gram', 'cumulative-1-gram', 'cumulative-2-gram', 'cumulative-3-gram', 'cumulative-4-gram'])
questions = qa_paired_test['Pertanyaan'].apply(lambda x: x.lower().replace('[BOS]', '').replace('[EOS]', '')).to_list()
answers = qa_paired_test['Jawaban'].apply(lambda x: x.replace('[BOS]', '').replace('[EOS]', '').lower().strip()).to_list()
questions_eval = qa_paired_eval['Pertanyaan'].apply(lambda x: x.lower().replace('[BOS]', '').replace('[EOS]', '')).to_list()
answers_eval = qa_paired_eval['Jawaban'].apply(lambda x: x.replace('[BOS]', '').replace('[EOS]', '').lower().strip()).to_list()

epochs = 500
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()

for ep in range(epochs):
    torch.cuda.empty_cache()

    total_loss = 0
    for instance in qa_paired_test.iterrows():
        # print("---------------")
        optimizer.zero_grad()

        pertanyaan = instance[1]['Pertanyaan']
        jawaban = instance[1]['Jawaban']
        jawaban_withpre = '[PRE1][PRE2][PRE3][PRE4][PRE5]' + jawaban

        tokenized_jawaban_withpre = model.dec_tokenizer(jawaban_withpre)
        tokenized_jawaban_withpre = torch.tensor(tokenized_jawaban_withpre['input_ids']).unsqueeze(0)

        enc_logits = model.encoding(pertanyaan)
        output = model.decoding_train(enc_logits, target=jawaban, target_with_pre=tokenized_jawaban_withpre)

        loss = output.loss
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

    print(f'Epoch {ep+1}/{epochs} - Loss: {total_loss:.4f}')
    if (ep+1) % 10 == 0:
        print(f'\n-----------------------------------------')
        test_question = qa_paired_test['Pertanyaan'].iloc[0]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        test_question = qa_paired_test['Pertanyaan'].iloc[1]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        test_question = qa_paired_test['Pertanyaan'].iloc[4]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        print(f'-----------------------------------------\n')

    if (ep+1) % 10 == 0:
        bleu_result = count_bleu_score(model, answers_eval, questions_eval)
        bleu_score = pd.concat([bleu_score, pd.DataFrame({'Epoch': ep+1, **bleu_result}, index=[len(bleu_score)])], ignore_index=True)

        print(f'BLEU Score: {bleu_result["cumulative-4-gram"]:.4f}\n')
# Out:
# Epoch 1/500 - Loss: 162.9523
# Epoch 2/500 - Loss: 116.7167
# Epoch 3/500 - Loss: 91.8914
# Epoch 4/500 - Loss: 72.6337
# Epoch 5/500 - Loss: 58.6814
# Epoch 6/500 - Loss: 50.7612
# Epoch 7/500 - Loss: 43.2203
# Epoch 8/500 - Loss: 33.1586
# Epoch 9/500 - Loss: 26.8153
# Epoch 10/500 - Loss: 23.5555
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< meningkatkan kualitas dan kuantitas pengabdian masyarakat melalui kegiatan pemberdayaan masyarakat, penelitian dan pengembangan, serta kerjasama.meningkatkan kualitas dan kuantitas penelitian dan pengembangan, serta kerjasama yang berorientasi pada peningkatan daya saing bangsa.meningkatkan kemandirian dan daya saing bangsa dalam pengembangan teknologi informasi dan komunikasi.meningkatkan peran serta masyarakat dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia industri dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia industri dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan peran serta dunia usaha dan dunia usaha dalam pembangunan.meningkatkan
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan tinggi yang berkualitas dan relevan dengan kebutuhan pembangunan, serta menghasilkan sumber daya manusia yang kompeten, profesional, dan berdaya saing tinggi.
# menyelenggarakan penelitian yang berkualitas dan menghasilkan inovasi yang dapat dimanfaatkan oleh masyarakat.
# menyelenggarakan pengabdian kepada masyarakat yang berkualitas dan menghasilkan.
# menyelenggarakan kerjasama yang sinergis dengan dunia usaha dan dunia industri.
# menyelenggarakan tata kelola organisasi yang baik.
# meny[PAD][PAD]ektur jendral pendidikan tinggi
# http://s.ub.ac.id/s[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Q >>> email fitra a. bachtiar
# A <<< affective computing, affective engineering, intelligent system, data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational data mining, educational
# -----------------------------------------
#
# BLEU Score: 0.2547
#
# Epoch 11/500 - Loss: 18.3302
# Epoch 12/500 - Loss: 16.0848
# Epoch 13/500 - Loss: 14.7760
# Epoch 14/500 - Loss: 12.3321
# Epoch 15/500 - Loss: 9.1053
# Epoch 16/500 - Loss: 8.8528
# Epoch 17/500 - Loss: 7.4532
# Epoch 18/500 - Loss: 5.9274
# Epoch 19/500 - Loss: 7.5549
# Epoch 20/500 - Loss: 5.1997
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional. [PRE5] [PAD]
# menyelenggarakan pendidikan, penelitian, dan pengabdian kepada masyarakat yang berkualitas.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# mewujudkan tata kelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# mewujudkan tata kelola keuangan yang transparan, akuntabel, dan bertanggung jawab.
# mewujudkan tata kelola organisasi yang
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.5583
#
# Epoch 21/500 - Loss: 3.4674
# Epoch 22/500 - Loss: 6.3584
# Epoch 23/500 - Loss: 6.8239
# Epoch 24/500 - Loss: 6.1331
# Epoch 25/500 - Loss: 4.0047
# Epoch 26/500 - Loss: 3.9117
# Epoch 27/500 - Loss: 2.6191
# Epoch 28/500 - Loss: 2.5659
# Epoch 29/500 - Loss: 1.6934
# Epoch 30/500 - Loss: 1.9614
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< meningkatkan kompetensi dan kualifikasi pendidikan dosen meningkatkan sarana dan prasarana pembelajaran mengembangkan kurikulum mengkuti perkembangan dan kebutuhan pemangku kepentingan meningkatkan mutu lulusan yang berkualitas mempercepat masa studi meningkatkan kompetensi lulusan tersertifikasi bidang tik
# meningkatkan prestasi mahasiswa meningkatkan mutu kelembagaan
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.5707
#
# Epoch 31/500 - Loss: 2.4805
# Epoch 32/500 - Loss: 1.4132
# Epoch 33/500 - Loss: 1.3523
# Epoch 34/500 - Loss: 2.4513
# Epoch 35/500 - Loss: 1.6143
# Epoch 36/500 - Loss: 0.7473
# Epoch 37/500 - Loss: 0.6882
# Epoch 38/500 - Loss: 0.6733
# Epoch 39/500 - Loss: 0.4074
# Epoch 40/500 - Loss: 0.3863
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7080
#
# Epoch 41/500 - Loss: 0.3779
# Epoch 42/500 - Loss: 0.5538
# Epoch 43/500 - Loss: 0.3365
# Epoch 44/500 - Loss: 0.2697
# Epoch 45/500 - Loss: 0.2694
# Epoch 46/500 - Loss: 0.2374
# Epoch 47/500 - Loss: 0.2084
# Epoch 48/500 - Loss: 0.2047
# Epoch 49/500 - Loss: 0.1916
# Epoch 50/500 - Loss: 0.1826
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7958
#
# Epoch 51/500 - Loss: 0.1621
# Epoch 52/500 - Loss: 0.1828
# Epoch 53/500 - Loss: 0.2677
# Epoch 54/500 - Loss: 0.2380
# Epoch 55/500 - Loss: 0.1672
# Epoch 56/500 - Loss: 0.1808
# Epoch 57/500 - Loss: 0.1360
# Epoch 58/500 - Loss: 0.1133
# Epoch 59/500 - Loss: 0.1092
# Epoch 60/500 - Loss: 0.1191
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7700
#
# Epoch 61/500 - Loss: 0.1245
# Epoch 62/500 - Loss: 0.1875
# Epoch 63/500 - Loss: 0.4010
# Epoch 64/500 - Loss: 0.2930
# Epoch 65/500 - Loss: 0.1747
# Epoch 66/500 - Loss: 0.1212
# Epoch 67/500 - Loss: 0.1473
# Epoch 68/500 - Loss: 0.1711
# Epoch 69/500 - Loss: 0.1647
# Epoch 70/500 - Loss: 0.2173
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7297
#
# Epoch 71/500 - Loss: 0.2187
# Epoch 72/500 - Loss: 0.1495
# Epoch 73/500 - Loss: 0.2552
# Epoch 74/500 - Loss: 0.3539
# Epoch 75/500 - Loss: 0.2442
# Epoch 76/500 - Loss: 0.1904
# Epoch 77/500 - Loss: 0.1214
# Epoch 78/500 - Loss: 0.1267
# Epoch 79/500 - Loss: 0.1415
# Epoch 80/500 - Loss: 0.1185
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.8093
#
# Epoch 81/500 - Loss: 0.0947
# Epoch 82/500 - Loss: 0.0686
# Epoch 83/500 - Loss: 0.0674
# Epoch 84/500 - Loss: 0.0950
# Epoch 85/500 - Loss: 0.1492
# Epoch 86/500 - Loss: 0.1041
# Epoch 87/500 - Loss: 0.0600
# Epoch 88/500 - Loss: 0.0530
# Epoch 89/500 - Loss: 0.0898
# Epoch 90/500 - Loss: 0.1788
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7941
#
# Epoch 91/500 - Loss: 0.1442
# Epoch 92/500 - Loss: 0.0627
# Epoch 93/500 - Loss: 0.1669
# Epoch 94/500 - Loss: 0.1512
# Epoch 95/500 - Loss: 0.0660
# Epoch 96/500 - Loss: 0.0505
# Epoch 97/500 - Loss: 0.0900
# Epoch 98/500 - Loss: 0.1786
# Epoch 99/500 - Loss: 0.1054
# Epoch 100/500 - Loss: 0.0787
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.8453
#
# Epoch 101/500 - Loss: 0.1101
# Epoch 102/500 - Loss: 0.0770
# Epoch 103/500 - Loss: 0.0589
# Epoch 104/500 - Loss: 0.0543
# Epoch 105/500 - Loss: 0.0793
# Epoch 106/500 - Loss: 0.1084
# Epoch 107/500 - Loss: 0.0803
# Epoch 108/500 - Loss: 0.0337
# Epoch 109/500 - Loss: 0.0256
# Epoch 110/500 - Loss: 0.0222
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.8197
#
# Epoch 111/500 - Loss: 0.0269
# Epoch 112/500 - Loss: 0.1267
# Epoch 113/500 - Loss: 2.3098
# Epoch 114/500 - Loss: 127.5886
# Epoch 115/500 - Loss: 292.2474
# Epoch 116/500 - Loss: 238.7887
# Epoch 117/500 - Loss: 202.7624
# Epoch 118/500 - Loss: 175.1782
# Epoch 119/500 - Loss: 151.4618
# Epoch 120/500 - Loss: 128.2948
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< ad. s.kom., m.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.
# Q >>> misi filkom
# A <<< 1. s.kom., m.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.sc.itasi.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# 2.
# .
# 2.
# .
# .
# 2.
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# Q >>> email fitra a. bachtiar
# A <<<  fn. f. f. f f. f. f. f
#  f. f. f.
#
# ac.
#
#
#
#
# ac.
#
#
# sm.
#
# sm.
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# ..
# .
# ..
# ...
# .
# .
#
# [PAD] [PRE4]
#
#
# ./
#
#
#
#
#
#
#
#
#
#
#
# id.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .)
#
#
#
#
#
#
#
#
#
# -----------------------------------------
#
# BLEU Score: 0.0126
#
# Epoch 121/500 - Loss: 104.3840
# Epoch 122/500 - Loss: 87.1356
# Epoch 123/500 - Loss: 69.1444
# Epoch 124/500 - Loss: 59.0426
# Epoch 125/500 - Loss: 48.5907
# Epoch 126/500 - Loss: 44.1648
# Epoch 127/500 - Loss: 37.5411
# Epoch 128/500 - Loss: 32.4553
# Epoch 129/500 - Loss: 29.1331
# Epoch 130/500 - Loss: 28.5524
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< meningkatkan kompetensi sdm. es.meningkatkan sdm.essilulusan mahasiswa Magisterternatalulusan mahasiswa magisterternatalulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana lulusan sarjana l
# Q >>> misi filkom
# A <<< meningkatkan kompetensi dan lumenkolisium, s.kom., m.pd.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.0957
#
# Epoch 131/500 - Loss: 24.6886
# Epoch 132/500 - Loss: 20.7047
# Epoch 133/500 - Loss: 17.4847
# Epoch 134/500 - Loss: 16.7750
# Epoch 135/500 - Loss: 16.9138
# Epoch 136/500 - Loss: 12.1229
# Epoch 137/500 - Loss: 8.5777
# Epoch 138/500 - Loss: 6.1955
# Epoch 139/500 - Loss: 7.2136
# Epoch 140/500 - Loss: 5.9406
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< meningkatkan kompetensi dan kualifikasi pendidikan dosen meningkatkan sarana dan prasarana pembelajaran mengembangkan kurikulum mengkuti perkembangan dan kebutuhan pemangku kepentingan meningkatkan mutu lulusan yang berkualitas mempercepat masa studi meningkatkan kompetensi lulusan tersertifikasi bidang tik
# meningkatkan prestasi mahasiswa meningkatkan mutu kelembagaan
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.4304
#
# Epoch 141/500 - Loss: 5.9247
# Epoch 142/500 - Loss: 10.2515
# Epoch 143/500 - Loss: 11.2826
# Epoch 144/500 - Loss: 7.5936
# Epoch 145/500 - Loss: 5.8377
# Epoch 146/500 - Loss: 3.4020
# Epoch 147/500 - Loss: 3.0318
# Epoch 148/500 - Loss: 2.4298
# Epoch 149/500 - Loss: 1.7865
# Epoch 150/500 - Loss: 1.5449
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.4919
#
# Epoch 151/500 - Loss: 1.7218
# Epoch 152/500 - Loss: 1.2048
# Epoch 153/500 - Loss: 1.4727
# Epoch 154/500 - Loss: 1.1189
# Epoch 155/500 - Loss: 1.1939
# Epoch 156/500 - Loss: 0.8270
# Epoch 157/500 - Loss: 1.0551
# Epoch 158/500 - Loss: 1.8335
# Epoch 159/500 - Loss: 1.1135
# Epoch 160/500 - Loss: 1.0590
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.5664
#
# Epoch 161/500 - Loss: 0.8374
# Epoch 162/500 - Loss: 0.9179
# Epoch 163/500 - Loss: 0.5272
# Epoch 164/500 - Loss: 0.4156
# Epoch 165/500 - Loss: 0.5184
# Epoch 166/500 - Loss: 0.4550
# Epoch 167/500 - Loss: 0.4074
# Epoch 168/500 - Loss: 0.3611
# Epoch 169/500 - Loss: 0.4442
# Epoch 170/500 - Loss: 0.3987
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6320
#
# Epoch 171/500 - Loss: 0.3373
# Epoch 172/500 - Loss: 0.3084
# Epoch 173/500 - Loss: 0.3307
# Epoch 174/500 - Loss: 0.4412
# Epoch 175/500 - Loss: 0.3338
# Epoch 176/500 - Loss: 0.2792
# Epoch 177/500 - Loss: 0.2847
# Epoch 178/500 - Loss: 0.2872
# Epoch 179/500 - Loss: 0.2766
# Epoch 180/500 - Loss: 0.2583
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6474
#
# Epoch 181/500 - Loss: 0.2531
# Epoch 182/500 - Loss: 0.2513
# Epoch 183/500 - Loss: 0.2450
# Epoch 184/500 - Loss: 0.2371
# Epoch 185/500 - Loss: 0.2576
# Epoch 186/500 - Loss: 0.2590
# Epoch 187/500 - Loss: 0.2558
# Epoch 188/500 - Loss: 0.2346
# Epoch 189/500 - Loss: 0.2271
# Epoch 190/500 - Loss: 0.2178
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6545
#
# Epoch 191/500 - Loss: 0.2266
# Epoch 192/500 - Loss: 0.2333
# Epoch 193/500 - Loss: 0.2505
# Epoch 194/500 - Loss: 0.2200
# Epoch 195/500 - Loss: 0.2216
# Epoch 196/500 - Loss: 0.2365
# Epoch 197/500 - Loss: 0.2416
# Epoch 198/500 - Loss: 0.2067
# Epoch 199/500 - Loss: 0.1981
# Epoch 200/500 - Loss: 0.1937
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6305
#
# Epoch 201/500 - Loss: 0.1838
# Epoch 202/500 - Loss: 0.1930
# Epoch 203/500 - Loss: 0.2247
# Epoch 204/500 - Loss: 0.2430
# Epoch 205/500 - Loss: 0.2618
# Epoch 206/500 - Loss: 0.3737
# Epoch 207/500 - Loss: 2.2436
# Epoch 208/500 - Loss: 9.0885
# Epoch 209/500 - Loss: 48.0471
# Epoch 210/500 - Loss: 73.4664
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< 1. menyediakan diri sendiri, menyediakan diri sendiri, menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya sendiri menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya sendiri menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya sendiri menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya menyediakan dirinya sendiri menyediakan dirinya sendiri menyediakan dirinya sendiri menyediakan dirinya sendiri menyediakan dirinya sendiri menyediakan dirinya sendiri menyediakan dirinya sendiri menyediakan dirinya
# Q >>> misi filkom
# A <<< 1. menyediakan diri untuk menyediakan diri untuk menyediakan diri secara berkesinambungan.
# 2. menyediakan diri secara berkesinambungan.
# 3. menyediakan dirinya secara berkesinambungan.
# 3. berkesinambungan dengan menyediakan satuan waktu yang berkesinambungan dengan menyediakan satuan waktu yang berkesinambungan dengan menyediakan satuan waktu yang berkesinambungan dengan menyediakan satuan waktu jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka panjang jangka
# Q >>> email fitra a. bachtiar
# A <<< layanan bimbingan dan konseling dapat diakses pada tautan berikut :
# https://s.ub.ac.id/kemahasiswaan/layanan-layanan-sen
# -----------------------------------------
#
# BLEU Score: 0.0578
#
# Epoch 211/500 - Loss: 68.1648
# Epoch 212/500 - Loss: 37.6747
# Epoch 213/500 - Loss: 22.0995
# Epoch 214/500 - Loss: 16.1780
# Epoch 215/500 - Loss: 12.8633
# Epoch 216/500 - Loss: 8.1448
# Epoch 217/500 - Loss: 6.7316
# Epoch 218/500 - Loss: 5.9900
# Epoch 219/500 - Loss: 3.8124
# Epoch 220/500 - Loss: 2.2478
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< meningkatkan kompetensi dan kualifikasi pendidikan dosen meningkatkan sarana dan prasarana pembelajaran mengembangkan kurikulum mengkuti perkembangan dan kebutuhan pemangku kepentingan meningkatkan mutu lulusan yang berkualitas mempercepat masa studi meningkatkan kompetensi lulusan tersertifikasi bidang tik
# meningkatkan prestasi mahasiswa meningkatkan mutu kelembagaan
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.5211
#
# Epoch 221/500 - Loss: 2.0698
# Epoch 222/500 - Loss: 1.4974
# Epoch 223/500 - Loss: 1.7903
# Epoch 224/500 - Loss: 1.4256
# Epoch 225/500 - Loss: 1.3175
# Epoch 226/500 - Loss: 1.0265
# Epoch 227/500 - Loss: 0.6986
# Epoch 228/500 - Loss: 0.8654
# Epoch 229/500 - Loss: 1.0393
# Epoch 230/500 - Loss: 0.7650
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6728
#
# Epoch 231/500 - Loss: 0.5582
# Epoch 232/500 - Loss: 0.8927
# Epoch 233/500 - Loss: 1.2150
# Epoch 234/500 - Loss: 0.8400
# Epoch 235/500 - Loss: 0.5599
# Epoch 236/500 - Loss: 0.9885
# Epoch 237/500 - Loss: 1.7218
# Epoch 238/500 - Loss: 0.5268
# Epoch 239/500 - Loss: 0.3538
# Epoch 240/500 - Loss: 0.4230
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6540
#
# Epoch 241/500 - Loss: 0.4770
# Epoch 242/500 - Loss: 0.5283
# Epoch 243/500 - Loss: 0.7663
# Epoch 244/500 - Loss: 0.3936
# Epoch 245/500 - Loss: 0.3264
# Epoch 246/500 - Loss: 0.3989
# Epoch 247/500 - Loss: 0.3412
# Epoch 248/500 - Loss: 0.3365
# Epoch 249/500 - Loss: 0.2447
# Epoch 250/500 - Loss: 0.2424
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6794
#
# Epoch 251/500 - Loss: 0.2415
# Epoch 252/500 - Loss: 0.2322
# Epoch 253/500 - Loss: 0.2251
# Epoch 254/500 - Loss: 0.4361
# Epoch 255/500 - Loss: 0.3206
# Epoch 256/500 - Loss: 0.2569
# Epoch 257/500 - Loss: 0.2300
# Epoch 258/500 - Loss: 0.3173
# Epoch 259/500 - Loss: 0.2656
# Epoch 260/500 - Loss: 0.2034
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6933
#
# Epoch 261/500 - Loss: 0.1769
# Epoch 262/500 - Loss: 0.1893
# Epoch 263/500 - Loss: 0.2010
# Epoch 264/500 - Loss: 0.2382
# Epoch 265/500 - Loss: 0.2125
# Epoch 266/500 - Loss: 0.1631
# Epoch 267/500 - Loss: 0.1509
# Epoch 268/500 - Loss: 0.1745
# Epoch 269/500 - Loss: 0.2347
# Epoch 270/500 - Loss: 0.2155
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6657
#
# Epoch 271/500 - Loss: 0.1634
# Epoch 272/500 - Loss: 0.4660
# Epoch 273/500 - Loss: 0.2488
# Epoch 274/500 - Loss: 0.2659
# Epoch 275/500 - Loss: 0.3822
# Epoch 276/500 - Loss: 0.2281
# Epoch 277/500 - Loss: 0.1293
# Epoch 278/500 - Loss: 0.1085
# Epoch 279/500 - Loss: 0.1216
# Epoch 280/500 - Loss: 0.1551
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6968
#
# Epoch 281/500 - Loss: 0.1153
# Epoch 282/500 - Loss: 0.0984
# Epoch 283/500 - Loss: 0.1146
# Epoch 284/500 - Loss: 0.1303
# Epoch 285/500 - Loss: 0.0946
# Epoch 286/500 - Loss: 0.0846
# Epoch 287/500 - Loss: 0.1164
# Epoch 288/500 - Loss: 0.1373
# Epoch 289/500 - Loss: 0.0968
# Epoch 290/500 - Loss: 0.0781
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6833
#
# Epoch 291/500 - Loss: 0.0958
# Epoch 292/500 - Loss: 0.1273
# Epoch 293/500 - Loss: 0.0898
# Epoch 294/500 - Loss: 0.0777
# Epoch 295/500 - Loss: 0.0890
# Epoch 296/500 - Loss: 0.1262
# Epoch 297/500 - Loss: 0.0873
# Epoch 298/500 - Loss: 0.0875
# Epoch 299/500 - Loss: 0.1629
# Epoch 300/500 - Loss: 0.1655
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6453
#
# Epoch 301/500 - Loss: 0.0817
# Epoch 302/500 - Loss: 0.0831
# Epoch 303/500 - Loss: 0.1594
# Epoch 304/500 - Loss: 0.1138
# Epoch 305/500 - Loss: 0.0690
# Epoch 306/500 - Loss: 0.0631
# Epoch 307/500 - Loss: 0.1105
# Epoch 308/500 - Loss: 0.1237
# Epoch 309/500 - Loss: 0.0927
# Epoch 310/500 - Loss: 0.0907
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.6723
#
# Epoch 311/500 - Loss: 0.1116
# Epoch 312/500 - Loss: 0.0924
# Epoch 313/500 - Loss: 0.0679
# Epoch 314/500 - Loss: 0.0663
# Epoch 315/500 - Loss: 0.0863
# Epoch 316/500 - Loss: 0.1384
# Epoch 317/500 - Loss: 0.1248
# Epoch 318/500 - Loss: 0.0654
# Epoch 319/500 - Loss: 0.0423
# Epoch 320/500 - Loss: 0.0720
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# ...
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7799
#
# Epoch 391/500 - Loss: 0.0158
# Epoch 392/500 - Loss: 0.0154
# Epoch 393/500 - Loss: 0.0150
# Epoch 394/500 - Loss: 0.0147
# Epoch 395/500 - Loss: 0.0143
# Epoch 396/500 - Loss: 0.0139
# Epoch 397/500 - Loss: 0.0136
# Epoch 398/500 - Loss: 0.0133
# Epoch 399/500 - Loss: 0.0130
# Epoch 400/500 - Loss: 0.0127
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7799
#
# Epoch 401/500 - Loss: 0.0124
# Epoch 402/500 - Loss: 0.0121
# Epoch 403/500 - Loss: 0.0118
# Epoch 404/500 - Loss: 0.0115
# Epoch 405/500 - Loss: 0.0112
# Epoch 406/500 - Loss: 0.0110
# Epoch 407/500 - Loss: 0.0107
# Epoch 408/500 - Loss: 0.0105
# Epoch 409/500 - Loss: 0.0103
# Epoch 410/500 - Loss: 0.0100
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7698
#
# Epoch 411/500 - Loss: 0.0098
# Epoch 412/500 - Loss: 0.0096
# Epoch 413/500 - Loss: 0.0094
# Epoch 414/500 - Loss: 0.0092
# Epoch 415/500 - Loss: 0.0090
# Epoch 416/500 - Loss: 0.0088
# Epoch 417/500 - Loss: 0.0086
# Epoch 418/500 - Loss: 0.0084
# Epoch 419/500 - Loss: 0.0082
# Epoch 420/500 - Loss: 0.0080
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7698
#
# Epoch 421/500 - Loss: 0.0079
# Epoch 422/500 - Loss: 0.0077
# Epoch 423/500 - Loss: 0.0075
# Epoch 424/500 - Loss: 0.0074
# Epoch 425/500 - Loss: 0.0072
# Epoch 426/500 - Loss: 0.0071
# Epoch 427/500 - Loss: 0.0069
# Epoch 428/500 - Loss: 0.0068
# Epoch 429/500 - Loss: 0.0066
# Epoch 430/500 - Loss: 0.0065
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7725
#
# Epoch 431/500 - Loss: 0.0063
# Epoch 432/500 - Loss: 0.0062
# Epoch 433/500 - Loss: 0.0061
# Epoch 434/500 - Loss: 0.0059
# Epoch 435/500 - Loss: 0.0058
# Epoch 436/500 - Loss: 0.0057
# Epoch 437/500 - Loss: 0.0056
# Epoch 438/500 - Loss: 0.0055
# Epoch 439/500 - Loss: 0.0054
# Epoch 440/500 - Loss: 0.0052
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7725
#
# Epoch 441/500 - Loss: 0.0051
# Epoch 442/500 - Loss: 0.0050
# Epoch 443/500 - Loss: 0.0049
# Epoch 444/500 - Loss: 0.0048
# Epoch 445/500 - Loss: 0.0047
# Epoch 446/500 - Loss: 0.0046
# Epoch 447/500 - Loss: 0.0045
# Epoch 448/500 - Loss: 0.0044
# Epoch 449/500 - Loss: 0.0044
# Epoch 450/500 - Loss: 0.0043
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7725
#
# Epoch 451/500 - Loss: 0.0042
# Epoch 452/500 - Loss: 0.0041
# Epoch 453/500 - Loss: 0.0040
# Epoch 454/500 - Loss: 0.0039
# Epoch 455/500 - Loss: 0.0039
# Epoch 456/500 - Loss: 0.0038
# Epoch 457/500 - Loss: 0.0037
# Epoch 458/500 - Loss: 0.0036
# Epoch 459/500 - Loss: 0.0036
# Epoch 460/500 - Loss: 0.0035
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7725
#
# Epoch 461/500 - Loss: 0.0034
# Epoch 462/500 - Loss: 0.0033
# Epoch 463/500 - Loss: 0.0033
# Epoch 464/500 - Loss: 0.0032
# Epoch 465/500 - Loss: 0.0031
# Epoch 466/500 - Loss: 0.0031
# Epoch 467/500 - Loss: 0.0030
# Epoch 468/500 - Loss: 0.0030
# Epoch 469/500 - Loss: 0.0029
# Epoch 470/500 - Loss: 0.0028
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7590
#
# Epoch 471/500 - Loss: 0.0028
# Epoch 472/500 - Loss: 0.0027
# Epoch 473/500 - Loss: 0.0027
# Epoch 474/500 - Loss: 0.0026
# Epoch 475/500 - Loss: 0.0026
# Epoch 476/500 - Loss: 0.0025
# Epoch 477/500 - Loss: 0.0025
# Epoch 478/500 - Loss: 0.0024
# Epoch 479/500 - Loss: 0.0024
# Epoch 480/500 - Loss: 0.0023
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7590
#
# Epoch 481/500 - Loss: 0.0023
# Epoch 482/500 - Loss: 0.0022
# Epoch 483/500 - Loss: 0.0022
# Epoch 484/500 - Loss: 0.0021
# Epoch 485/500 - Loss: 0.0021
# Epoch 486/500 - Loss: 0.0021
# Epoch 487/500 - Loss: 0.0020
# Epoch 488/500 - Loss: 0.0020
# Epoch 489/500 - Loss: 0.0019
# Epoch 490/500 - Loss: 0.0019
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7591
#
# Epoch 491/500 - Loss: 0.0019
# Epoch 492/500 - Loss: 0.0018
# Epoch 493/500 - Loss: 0.0018
# Epoch 494/500 - Loss: 0.0018
# Epoch 495/500 - Loss: 0.0017
# Epoch 496/500 - Loss: 0.0017
# Epoch 497/500 - Loss: 0.0017
# Epoch 498/500 - Loss: 0.0016
# Epoch 499/500 - Loss: 0.0016
# Epoch 500/500 - Loss: 0.0016
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score: 0.7859

# %%
bleu_score.to_excel('bleu_score_091024.xlsx', index=False)

# %%
bleu_score
# Out:
#    Epoch    1-gram    2-gram    3-gram    4-gram  cumulative-1-gram  \
# 0     10  0.317903  0.277989  0.259834  0.224506           0.317903
# 1     20  0.613059  0.570751  0.563761  0.534826           0.613059
# 2     30  0.635755  0.578430  0.576549  0.551616           0.635755
# 3     40  0.752570  0.717353  0.715729  0.690370           0.752570
# 4     50  0.833898  0.805582  0.804177  0.778775           0.833898
# 5     60  0.814146  0.778995  0.777848  0.752881           0.814146
# 6     70  0.775928  0.738504  0.737379  0.712456           0.775928
# 7     80  0.846794  0.819006  0.817682  0.792279           0.846794
# 8     90  0.828370  0.804071  0.802895  0.778046           0.828370
# 9    100  0.879408  0.855084  0.854369  0.829385           0.879408
# 10   110  0.849420  0.830319  0.829110  0.803667           0.849420
# 11   120  0.043192  0.017546  0.006645  0.007702           0.043192
# 12   130  0.154454  0.115709  0.099489  0.075410           0.154454
# 13   140  0.486552  0.447049  0.438267  0.409517           0.486552
# 14   150  0.529691  0.506119  0.501363  0.474354           0.529691
# 15   160  0.603216  0.581372  0.574811  0.546426           0.603216
# 16   170  0.673786  0.643771  0.639494  0.612744           0.673786
# 17   180  0.689696  0.657858  0.655104  0.629016           0.689696
# 18   190  0.693398  0.664768  0.662778  0.637335           0.693398
# 19   200  0.674507  0.641678  0.638200  0.611329           0.674507
# 20   210  0.106123  0.072663  0.057050  0.039459           0.106123
# 21   220  0.591020  0.534827  0.526582  0.498555           0.591020
# 22   230  0.718532  0.682297  0.680177  0.654779           0.718532
# 23   240  0.705094  0.665836  0.660960  0.635690           0.705094
# 24   250  0.729961  0.687759  0.686557  0.661743           0.729961
# 25   260  0.738297  0.701901  0.701069  0.676584           0.738297
# 26   270  0.715158  0.675539  0.673235  0.647122           0.715158
# 27   280  0.737637  0.707526  0.705662  0.679609           0.737637
# 28   290  0.724702  0.694032  0.692169  0.666117           0.724702
# 29   300  0.687828  0.655845  0.654017  0.628261           0.687828
# 30   310  0.714717  0.682896  0.681067  0.655310           0.714717
# 31   320  0.671564  0.630959  0.627643  0.602091           0.671564
# 32   330  0.424118  0.368413  0.359237  0.332367           0.424118
# 33   340  0.555154  0.511624  0.510423  0.485330           0.555154
# 34   350  0.823230  0.795105  0.792142  0.765285           0.823230
# 35   360  0.839823  0.813240  0.809578  0.782541           0.839823
# 36   370  0.808616  0.781645  0.779026  0.752660           0.808616
# 37   380  0.806384  0.780825  0.778598  0.752631           0.806384
# 38   390  0.816395  0.790887  0.788595  0.762557           0.816395
# 39   400  0.816395  0.790887  0.788595  0.762557           0.816395
# 40   410  0.806262  0.780811  0.778581  0.752612           0.806262
# 41   420  0.806262  0.780811  0.778581  0.752612           0.806262
# 42   430  0.808049  0.782744  0.780708  0.754926           0.808049
# 43   440  0.808049  0.782744  0.780708  0.754926           0.808049
# 44   450  0.808049  0.782744  0.780708  0.754926           0.808049
# 45   460  0.808049  0.782744  0.780708  0.754926           0.808049
# 46   470  0.794535  0.769231  0.767195  0.741412           0.794535
# 47   480  0.794617  0.769239  0.767203  0.741421           0.794617
# 48   490  0.795465  0.769279  0.767245  0.741465           0.795465
# 49   500  0.820953  0.796115  0.794214  0.768431           0.820953
#
#     cumulative-2-gram  cumulative-3-gram  cumulative-4-gram
# 0            0.290375           0.275411           0.254706
# 1            0.583945           0.576203           0.558345
# 2            0.593836           0.586729           0.570738
# 3            0.727762           0.723049           0.708010
# 4            0.814290           0.810285           0.795817
# 5            0.789003           0.784596           0.770034
# 6            0.748897           0.744316           0.729706
# 7            0.827569           0.823715           0.809284
# 8            0.811375           0.807967           0.794108
# 9            0.862379           0.859164           0.845308
# 10           0.836230           0.833497           0.819745
# 11           0.024968           0.015761           0.012586
# 12           0.127455           0.113554           0.095692
# 13           0.457967           0.448328           0.430403
# 14           0.513009           0.507957           0.491870
# 15           0.588964           0.583289           0.566408
# 16           0.652839           0.647346           0.631970
# 17           0.666599           0.662089           0.647417
# 18           0.672405           0.668572           0.654505
# 19           0.650763           0.645688           0.630485
# 20           0.085367           0.073921           0.057754
# 21           0.550508           0.539496           0.521113
# 22           0.692511           0.687395           0.672828
# 23           0.677354           0.669295           0.653992
# 24           0.698762           0.693758           0.679383
# 25           0.711522           0.707196           0.693287
# 26           0.686631           0.681170           0.665685
# 27           0.715872           0.711571           0.696800
# 28           0.702466           0.698123           0.683333
# 29           0.664657           0.660125           0.645259
# 30           0.691716           0.687189           0.672317
# 31           0.641418           0.635181           0.619816
# 32           0.384609           0.373292           0.354812
# 33           0.523342           0.517954           0.502927
# 34           0.803930           0.799218           0.783459
# 35           0.822355           0.817423           0.801570
# 36           0.790080           0.785595           0.770291
# 37           0.788720           0.784652           0.769866
# 38           0.798783           0.794708           0.779881
# 39           0.798783           0.794708           0.779881
# 40           0.788679           0.784620           0.769839
# 41           0.788679           0.784620           0.769839
# 42           0.790601           0.786735           0.772475
# 43           0.790601           0.786735           0.772475
# 44           0.790601           0.786735           0.772475
# 45           0.790601           0.786735           0.772475
# 46           0.777088           0.773222           0.758962
# 47           0.777114           0.773241           0.758977
# 48           0.777299           0.773359           0.759066
# 49           0.803820           0.800160           0.785941

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(bleu_score['Epoch'], bleu_score['1-gram'], label='1-gram')
plt.plot(bleu_score['Epoch'], bleu_score['2-gram'], label='2-gram')
plt.plot(bleu_score['Epoch'], bleu_score['3-gram'], label='3-gram')
plt.plot(bleu_score['Epoch'], bleu_score['4-gram'], label='4-gram')
plt.plot(bleu_score['Epoch'], bleu_score['cumulative-1-gram'], label='cumulative-1-gram')
plt.plot(bleu_score['Epoch'], bleu_score['cumulative-2-gram'], label='cumulative-2-gram')
plt.plot(bleu_score['Epoch'], bleu_score['cumulative-3-gram'], label='cumulative-3-gram')
plt.plot(bleu_score['Epoch'], bleu_score['cumulative-4-gram'], label='cumulative-4-gram')
plt.xlabel('Epoch')
plt.ylabel('BLEU Score')
plt.ylim(0, 1)
plt.title('BLEU Score on 5 PRE Token')
plt.legend()
# add number for each 100 epoch

# %%
bleu_result_2 = count_bleu_score(model, answers, questions)
bleu_result_2
# Out:
# {'1-gram': 0.9768651030864939,
#  '2-gram': 0.9415404542175729,
#  '3-gram': 0.9370405952906978,
#  '4-gram': 0.8396151845702171,
#  'cumulative-1-gram': 0.9768651030864939,
#  'cumulative-2-gram': 0.9513911623347994,
#  'cumulative-3-gram': 0.9455563688405594,
#  'cumulative-4-gram': 0.894932663509144}

# %%
test_question = "fitra bachtiar penelitian apa "
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> fitra bachtiar penelitian apa
# A <<< affective computing, affective engineering, intelligent system, data mining, educational data mining

# %%
test_question = "pak fitra topik penelitian"
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> pak fitra topik penelitian
# A <<< affective computing, affective engineering, intelligent system, data mining, educational data mining

# %%
test_question = "ketua bpj teh saha ieu"
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')

# %%
test_question = "sekdep sistem informasi teh saha"
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> sekdep sistem informasi teh saha
# A <<< satrio agung wicaksono, s.kom., m.kom

# %%
for i in range(len(qa_paired_eval)):
    test_question = qa_paired_eval['Pertanyaan'].iloc[i]
    outputs = model.generate(test_question)
    decoded_output = model.dec_tokenizer.decode(outputs[0])
    qa_paired_eval.loc[i, 'Predicted Answer'] = decoded_output

# %%
qa_paired_eval.to_excel('qa_paired_eval_091024_5PRE.xlsx', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
torch.save(model.state_dict(), 'FLUENTSOTA_091024.pth')

# %%
state_dict = torch.load('FLUENTSOTA_051024.pth')
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>
