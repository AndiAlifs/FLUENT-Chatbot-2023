# %%
# !nvidia-smi
# Out:
# Sat Oct 12 16:05:28 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:47:00.0 Off |                    0 |
# | N/A   39C    P0    73W / 400W |  46647MiB / 81251MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from transformers import AutoTokenizer, AutoModel, GPT2LMHeadModel, GPT2Tokenizer
from sklearn.decomposition import PCA
from torch import nn
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import torch
import matplotlib.pyplot as plt
import time
import pandas as pd

# %%
# knowledgebase_url = 'https://github.com/AndiAlifs/FLUENT-Chatbot-2023/raw/main/KnowledgeBaseFilkom.xlsx'
knowledgebase_url = 'https://github.com/AndiAlifs/FLUENT-Chatbot-2023/raw/main/KnowledgeBaseFilkom_simple.xlsx'
knowledgebase = pd.read_excel(knowledgebase_url)

qa_paired = knowledgebase.drop(columns=knowledgebase.columns.drop(['Pertanyaan', 'Jawaban']))
qa_paired.dropna(inplace=True)
qa_paired
# Out:
#                                            Pertanyaan  \
# 0                                         visi filkom
# 1                                         misi filkom
# 2                                  apa tujuan filkom?
# 3                           sasaran pendidikan filkom
# 4                             email fitra a. bachtiar
# 5                 bidang penelitian fitra a. bachtiar
# 6                              tanggal dibentuk ptiik
# 7                           sasaran pengabdian filkom
# 8                            sasaran kerjasama filkom
# 9                 dekan fakultas ilmu komputer filkom
# 10        wakil dekan bidang akademik / wakil dekan 1
# 11  wakil dekan bidang umum, keuangan, dan sumber ...
# 12  wakil dekan bidang kemahasiswaan, alumni, dan ...
# 13                ketua departemen teknik informatika
# 14           sekretaris departemen teknik informatika
# 15         ketua program studi magister ilmu komputer
# 16     ketua program studi sarjana teknik informatika
# 17        ketua program studi sarjana teknik komputer
# 18                  ketua departemen sistem informasi
# 19              seketaris departemen sistem informasi
# 20       ketua program studi sarjana sistem informasi
# 21  ketua program studi sarjana pendidikan teknolo...
# 22    ketua program studi sarjana teknologi informasi
# 23                      berikan saya informasi alumni
# 24         apa saja layanan kemahasiswaan filkom ub ?
# 25  bagaimana pengajuan proposal dan lpj kegiatan ...
# 26          berikan informasi dokumen kemahasiswaan ?
# 27  bagaimana pengajuan surat tugas dosen pembimbi...
# 28           bagaimana permohonan validasi data skm ?
# 29  berikan informasi mengenai validasi syarat wisuda
# 30        bagaimana mengakses tracer study fakultas ?
# 31          bagaimana cara pendaftaran wisuda ulang ?
# 32  berikan informasi mengenai layanan bimbingan d...
# 33  berikan informasi mengenai layanan ultksp (uni...
# 34  berikan informasi mengenai tracking layanan ke...
# 35  berikan informasi mengenai bimbingan dan konse...
# 36                        apa tujuan unit konseling ?
# 37  apa fungsi bimbingan dan konseling serta penas...
# 38          apa saja program layanan unit konseling ?
# 39                     apa manfaat konseling filkom ?
# 40       berikan informasi mengenai layanan konseling
# 41  siapa konselor bimbingan dan konseling di filk...
# 42                siapa koordinator konselor sebaya ?
# 43                     berikan rincian layanan ultksp
#
#                                               Jawaban
# 0   menjadi fakultas yang berdaya saing internasio...
# 1   menyelenggarakan pendidikan di bidang teknolog...
# 2   menghasilkan lulusan yang kompeten , profesion...
# 3   meningkatkan kompetensi dan kualifikasi pendid...
# 4                          fitra.bachtiar[at]ub.ac.id
# 5   affective computing, affective engineering, in...
# 6                                     27 oktober 2011
# 7   1. meningkatkan kualitas dan kuantitas pengabd...
# 8   1. mengadakan kerjasama pendidikan, penlitian ...
# 9   prof. ir. wayan firdaus mahmudy, s.si., mt., p...
# 10                dr. eng. ir. herman tolle, st., mt.
# 11                      agus wahyu widodo, st., m.cs.
# 12                      drs. muh. arif rahman, m.kom.
# 13                  achmad basuki, s.t., m.mg., ph.d.
# 14               ir. primantara hari trisnawan, m.sc.
# 15      sabriansyah rizqika akbar, s.t., m.eng., ph.d
# 16                   adhitya bhawiyuga, s.kom., m.sc.
# 17       barlian henryranu prasetio, s.t., m.t., ph.d
# 18                         issa arwani, s.kom., m.sc.
# 19              satrio agung wicaksono, s.kom., m.kom
# 20                 yusi tyroni mursityo, s.kom., m.s.
# 21            ir. admaja dwi herlambang, s.pd., m.pd.
# 22  ir. widhy hayuhardhika nugraha putra, s.kom., ...
# 23  informasi alumni dapat diakses pada link berik...
# 24  1. pengajuan proposal dan lpj kegiatan kemahas...
# 25  pengajuan proposal kegiatan kemahasiswaan\npen...
# 26  informasi dokumen kemahasiswaan dapat dilihat ...
# 27  informasi pengajuan surat tugas dosen pembimbi...
# 28  permohonan validasi data skm dapat dilihat pad...
# 29  1. unggah dokumen di siam\n2. mengisi gform pe...
# 30  tracer study fakultas dapat diakses pada tauta...
# 31  pendaftaran wisuda ulang dapat diakses pada ta...
# 32  layanan bimbingan dan konseling dapat diaksesp...
# 33  layanan ultksp dapat diaksespada tautan beriku...
# 34  tracking layanan kemahasiswaan dapat diaksespa...
# 35  dalam perjalanannya menuntut ilmu, mahasiswa t...
# 36  1. mewujudkan potensi dirinya secara optimal, ...
# 37  1. penyaluran: bimbingan berfungsi dalam memba...
# 38  1. pelayanan bantuan pemecahan masalah, baik y...
# 39  1. masalah ditangani oleh ahli yang kompeten d...
# 40  informasi mengenai layanan konseling dapat dia...
# 41  ada 2 konselor bimbingan dan konseling di filk...
# 42  koordinator konselor sebaya adalah muhammad da...
# 43  rincian layanan ultksp dapat diakses pada taut...

# %%
knowledgebase_eval_url = 'https://github.com/AndiAlifs/FLUENT-Chatbot-2023/raw/main/KnowledgeBaseFilkom_eval.xlsx'
knowledgebase_eval = pd.read_excel(knowledgebase_eval_url)

qa_paired_eval = knowledgebase_eval.drop(columns=knowledgebase_eval.columns.drop(['Pertanyaan', 'Jawaban']))
qa_paired_eval.dropna(inplace=True)
qa_paired_eval
# Out:
#                                           Pertanyaan  \
# 0                                  apa visi fakultas
# 1                                  visi dari filkokm
# 2                               apa saja visi filkom
# 3                                  apa misi fakultas
# 4                                apa saja misi flkom
# ..                                               ...
# 69                      apa manfaat konseling filkom
# 70      berikan informasi mengenai layanan konseling
# 71  siapa konselor bimbingan dan konseling di filkom
# 72                 siapa koordinator konselor sebaya
# 73                    berikan rincian layanan ultksp
#
#                                               Jawaban
# 0   menjadi fakultas yang berdaya saing internasio...
# 1   menjadi fakultas yang berdaya saing internasio...
# 2   menjadi fakultas yang berdaya saing internasio...
# 3   menyelenggarakan pendidikan di bidang teknolog...
# 4   menyelenggarakan pendidikan di bidang teknolog...
# ..                                                ...
# 69  1. masalah ditangani oleh ahli yang kompeten d...
# 70  informasi mengenai layanan konseling dapat dia...
# 71  ada 2 konselor bimbingan dan konseling di filk...
# 72  koordinator konselor sebaya adalah muhammad da...
# 73  rincian layanan ultksp dapat diakses pada taut...
#
# [74 rows x 2 columns]

# %%
enc_tokenizer = AutoTokenizer.from_pretrained('firqaaa/indo-sentence-bert-base')
enc_model = AutoModel.from_pretrained('firqaaa/indo-sentence-bert-base')
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# model_name_dec = 'flax-community/gpt2-medium-indonesian'
model_name_dec = 'indonesian-nlp/gpt2-medium-indonesian'

dec_model = GPT2LMHeadModel.from_pretrained(model_name_dec)
dec_tokenizer = GPT2Tokenizer.from_pretrained(model_name_dec)

dec_tokenizer.add_tokens(['[PRE1]'])
dec_tokenizer.add_tokens(['[PRE2]'])
dec_tokenizer.add_tokens(['[PRE3]'])

dec_tokenizer.add_special_tokens({'pad_token': '[PAD]',
                                    'bos_token': '[BOS]',
                                    'eos_token': '[EOS]',
                                    'sep_token': '[SEP]',})

# Add a new token to the tokenizer
dec_model.config.pad_token_id = dec_tokenizer.pad_token_id
dec_model.config.bos_token_id = dec_tokenizer.bos_token_id
dec_model.config.eos_token_id = dec_tokenizer.eos_token_id
dec_model.config.sep_token_id = dec_tokenizer.sep_token_id

dec_model.resize_token_embeddings(len(dec_tokenizer))
# Out:
# Embedding(50264, 1024)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
enc_model = enc_model.to(device)
dec_model = dec_model.to(device)

# %%
qa_paired_test = qa_paired
qa_paired_test = qa_paired_test.applymap(lambda x: x.lower() if isinstance(x, str) else x)
qa_paired_test['Jawaban'] = qa_paired_test['Jawaban'].apply(lambda x: '[BOS]' + x + '[EOS]')
qa_paired_test = qa_paired_test.reset_index(drop=True)
qa_paired_test
# Out:
#                                            Pertanyaan  \
# 0                                         visi filkom
# 1                                         misi filkom
# 2                                  apa tujuan filkom?
# 3                           sasaran pendidikan filkom
# 4                             email fitra a. bachtiar
# 5                 bidang penelitian fitra a. bachtiar
# 6                              tanggal dibentuk ptiik
# 7                           sasaran pengabdian filkom
# 8                            sasaran kerjasama filkom
# 9                 dekan fakultas ilmu komputer filkom
# 10        wakil dekan bidang akademik / wakil dekan 1
# 11  wakil dekan bidang umum, keuangan, dan sumber ...
# 12  wakil dekan bidang kemahasiswaan, alumni, dan ...
# 13                ketua departemen teknik informatika
# 14           sekretaris departemen teknik informatika
# 15         ketua program studi magister ilmu komputer
# 16     ketua program studi sarjana teknik informatika
# 17        ketua program studi sarjana teknik komputer
# 18                  ketua departemen sistem informasi
# 19              seketaris departemen sistem informasi
# 20       ketua program studi sarjana sistem informasi
# 21  ketua program studi sarjana pendidikan teknolo...
# 22    ketua program studi sarjana teknologi informasi
# 23                      berikan saya informasi alumni
# 24         apa saja layanan kemahasiswaan filkom ub ?
# 25  bagaimana pengajuan proposal dan lpj kegiatan ...
# 26          berikan informasi dokumen kemahasiswaan ?
# 27  bagaimana pengajuan surat tugas dosen pembimbi...
# 28           bagaimana permohonan validasi data skm ?
# 29  berikan informasi mengenai validasi syarat wisuda
# 30        bagaimana mengakses tracer study fakultas ?
# 31          bagaimana cara pendaftaran wisuda ulang ?
# 32  berikan informasi mengenai layanan bimbingan d...
# 33  berikan informasi mengenai layanan ultksp (uni...
# 34  berikan informasi mengenai tracking layanan ke...
# 35  berikan informasi mengenai bimbingan dan konse...
# 36                        apa tujuan unit konseling ?
# 37  apa fungsi bimbingan dan konseling serta penas...
# 38          apa saja program layanan unit konseling ?
# 39                     apa manfaat konseling filkom ?
# 40       berikan informasi mengenai layanan konseling
# 41  siapa konselor bimbingan dan konseling di filk...
# 42                siapa koordinator konselor sebaya ?
# 43                     berikan rincian layanan ultksp
#
#                                               Jawaban
# 0   [BOS]menjadi fakultas yang berdaya saing inter...
# 1   [BOS]menyelenggarakan pendidikan di bidang tek...
# 2   [BOS]menghasilkan lulusan yang kompeten , prof...
# 3   [BOS]meningkatkan kompetensi dan kualifikasi p...
# 4               [BOS] fitra.bachtiar[at]ub.ac.id[EOS]
# 5   [BOS]affective computing, affective engineerin...
# 6                           [BOS]27 oktober 2011[EOS]
# 7   [BOS]1. meningkatkan kualitas dan kuantitas pe...
# 8   [BOS]1. mengadakan kerjasama pendidikan, penli...
# 9   [BOS]prof. ir. wayan firdaus mahmudy, s.si., m...
# 10      [BOS]dr. eng. ir. herman tolle, st., mt.[EOS]
# 11            [BOS]agus wahyu widodo, st., m.cs.[EOS]
# 12            [BOS]drs. muh. arif rahman, m.kom.[EOS]
# 13        [BOS]achmad basuki, s.t., m.mg., ph.d.[EOS]
# 14     [BOS]ir. primantara hari trisnawan, m.sc.[EOS]
# 15  [BOS]sabriansyah rizqika akbar, s.t., m.eng., ...
# 16         [BOS]adhitya bhawiyuga, s.kom., m.sc.[EOS]
# 17  [BOS]barlian henryranu prasetio, s.t., m.t., p...
# 18               [BOS]issa arwani, s.kom., m.sc.[EOS]
# 19    [BOS]satrio agung wicaksono, s.kom., m.kom[EOS]
# 20       [BOS]yusi tyroni mursityo, s.kom., m.s.[EOS]
# 21  [BOS]ir. admaja dwi herlambang, s.pd., m.pd.[EOS]
# 22  [BOS]ir. widhy hayuhardhika nugraha putra, s.k...
# 23  [BOS]informasi alumni dapat diakses pada link ...
# 24  [BOS]1. pengajuan proposal dan lpj kegiatan ke...
# 25  [BOS]pengajuan proposal kegiatan kemahasiswaan...
# 26  [BOS]informasi dokumen kemahasiswaan dapat dil...
# 27  [BOS]informasi pengajuan surat tugas dosen pem...
# 28  [BOS]permohonan validasi data skm dapat diliha...
# 29  [BOS]1. unggah dokumen di siam\n2. mengisi gfo...
# 30  [BOS]tracer study fakultas dapat diakses pada ...
# 31  [BOS]pendaftaran wisuda ulang dapat diakses pa...
# 32  [BOS]layanan bimbingan dan konseling dapat dia...
# 33  [BOS]layanan ultksp dapat diaksespada tautan b...
# 34  [BOS]tracking layanan kemahasiswaan dapat diak...
# 35  [BOS]dalam perjalanannya menuntut ilmu, mahasi...
# 36  [BOS]1. mewujudkan potensi dirinya secara opti...
# 37  [BOS]1. penyaluran: bimbingan berfungsi dalam ...
# 38  [BOS]1. pelayanan bantuan pemecahan masalah, b...
# 39  [BOS]1. masalah ditangani oleh ahli yang kompe...
# 40  [BOS]informasi mengenai layanan konseling dapa...
# 41  [BOS]ada 2 konselor bimbingan dan konseling di...
# 42  [BOS]koordinator konselor sebaya adalah muhamm...
# 43  [BOS]rincian layanan ultksp dapat diakses pada...

# %%
class FLUENTSOTA(nn.Module):
    def __init__(self, enc_model, dec_model, enc_tokenizer, dec_tokenizer, max_length=200):
        super(FLUENTSOTA, self).__init__()
        self.enc_model = enc_model
        self.dec_model = dec_model
        self.enc_tokenizer = enc_tokenizer
        self.dec_tokenizer = dec_tokenizer
        self.enc_mapper = nn.Linear(768, 1024)
        self.enc_mapper2 = nn.Linear(1024, 1024)
        self.prefix_nn = nn.Linear(1024, 1024)
        self.prefix_nn2 = nn.Linear(1024, 1024)
        self.prefix_nn3 = nn.Linear(1024, 1024)
        self.max_length = max_length
    
    def encoding(self, sentence):
        tokens = self.enc_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        tokens = tokens.to(device)
        with torch.no_grad():
            output = self.enc_model(**tokens)
        enc_logits = output.last_hidden_state.mean(dim=1)
        enc_logits = self.enc_mapper(enc_logits).to(device)
        enc_logits = self.enc_mapper2(enc_logits).to(device)
        return enc_logits

    def get_embedding(self, sentence):
        tokens = self.dec_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        tokens = tokens.to(device)
        wte = self.dec_model.get_input_embeddings()
        return wte(tokens['input_ids'])

    def dec_tokenizer(self, sentence):
        tokens = self.dec_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        return tokens

    def add_prefix(self, enc_logits):
        prefix_1 = self.prefix_nn(enc_logits)
        prefix_2 = self.prefix_nn2(enc_logits)
        prefix_3 = self.prefix_nn3(enc_logits)

        prefixs = torch.stack((prefix_1, prefix_2, prefix_3), dim=1)
        return prefixs

    def decoding(self, enc_logits, target):
        prefixs = self.add_prefix(enc_logits)
        embed = self.get_embedding(target)
        pref_with_embed = torch.cat((prefixs, embed), dim=1)
        output = self.dec_model(inputs_embeds=pref_with_embed)
        return output

    def decoding_train(self, enc_logits, target, target_with_pre):
        prefixs = self.add_prefix(enc_logits)
        embed = self.get_embedding(target)
        pref_with_embed = torch.cat((prefixs, embed), dim=1)
        output = self.dec_model(inputs_embeds=pref_with_embed, labels=target_with_pre)
        return output

    def generate(self, quest):
        enc_logits = self.encoding(quest)
        prefix_se = '[BOS]'
        prefix_dec_embed = self.get_embedding(prefix_se)
        prefixs = self.add_prefix(enc_logits)
        
        pref_with_embed = torch.cat((prefixs, prefix_dec_embed), dim=1)

        output = self.dec_model.generate(   inputs_embeds=pref_with_embed, 
                                            max_length=self.max_length, 
                                            pad_token_id=self.dec_model.config.eos_token_id)
        returned_output = []
        for i in range(len(output[0])):
            if output[0][i] != self.dec_model.config.eos_token_id:
                returned_output.append(output[0][i])
            else:
                break
        return torch.tensor(returned_output).unsqueeze(0)

# %%
for param in enc_model.parameters():
    param.requires_grad = False

for param in dec_model.parameters():
    param.requires_grad = False

for param in dec_model.transformer.h[:-15].parameters():
    param.requires_grad = True

for param in enc_model.encoder.layer[:-15].parameters():
    param.requires_grad = True

# %%
model = FLUENTSOTA(enc_model, dec_model, enc_tokenizer, dec_tokenizer)
model.to(device)
# Out:
# FLUENTSOTA(
#   (enc_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(50000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dec_model): GPT2LMHeadModel(
#     (transformer): GPT2Model(
#       (wte): Embedding(50264, 1024)
#       (wpe): Embedding(1024, 1024)
#       (drop): Dropout(p=0.0, inplace=False)
#       (h): ModuleList(
#         (0): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (9): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (10): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (11): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (12): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (13): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (14): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (15): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (16): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (17): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (18): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (19): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (20): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (21): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (22): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (23): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (lm_head): Linear(in_features=1024, out_features=50264, bias=False)
#   )
#   (enc_mapper): Linear(in_features=768, out_features=1024, bias=True)
#   (enc_mapper2): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn2): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn3): Linear(in_features=1024, out_features=1024, bias=True)
# )

# %%
all_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
untrainable_params = all_params - trainable_params

print(f'All parameters: {all_params:,}')
print(f'Trainable parameters: {trainable_params:,} ({trainable_params/all_params*100:.2f}%)')
print(f'Untrainable parameters: {untrainable_params:,} ({untrainable_params/all_params*100:.2f}%)')
# Out:
# All parameters: 484,257,536
# Trainable parameters: 118,351,872 (24.44%)
# Untrainable parameters: 365,905,664 (75.56%)

# %%
def calculate_bleu(preds, questions, answers):
    bleu_score_1 = 0
    bleu_score_2 = 0
    bleu_score_3 = 0
    bleu_score_4 = 0
    cum_bleu_score_1 = 0
    cum_bleu_score_2 = 0
    cum_bleu_score_3 = 0
    cum_bleu_score_4 = 0

    num_of_rows_calculated = 0
    smoothing_function = SmoothingFunction().method1

    for i, (question, real_answer) in enumerate(zip(questions, answers)):
        # print(f"Question: {question}")
        # print(f"Real Answer: {real_answer}")
        # print(f"Predicted Answer: {preds[i]}")
        refs = [real_answer.split(' ')]
        hyp = preds[i].split(' ')

        bleu_score_1 += sentence_bleu(refs, hyp, weights=(1,0,0,0), smoothing_function=smoothing_function)
        bleu_score_2 += sentence_bleu(refs, hyp, weights=(0,1,0,0), smoothing_function=smoothing_function)
        bleu_score_3 += sentence_bleu(refs, hyp, weights=(0,0,1,0), smoothing_function=smoothing_function)
        bleu_score_4 += sentence_bleu(refs, hyp, weights=(0,0,0,1), smoothing_function=smoothing_function)
        cum_bleu_score_1 += sentence_bleu(refs, hyp, weights=(1,0,0,0), smoothing_function=smoothing_function)
        cum_bleu_score_2 += sentence_bleu(refs, hyp, weights=(0.5,0.5,0,0), smoothing_function=smoothing_function)
        cum_bleu_score_3 += sentence_bleu(refs, hyp, weights=(0.33,0.33,0.33,0), smoothing_function=smoothing_function)
        cum_bleu_score_4 += sentence_bleu(refs, hyp, weights=(0.25,0.25,0.25,0.25), smoothing_function=smoothing_function)

        num_of_rows_calculated+=1

    results = {"1-gram": (bleu_score_1/num_of_rows_calculated),
                "2-gram": (bleu_score_2/num_of_rows_calculated),
                "3-gram": (bleu_score_3/num_of_rows_calculated),
                "4-gram": (bleu_score_4/num_of_rows_calculated),
                "cumulative-1-gram": (cum_bleu_score_1/num_of_rows_calculated),
                "cumulative-2-gram": (cum_bleu_score_2/num_of_rows_calculated),
                "cumulative-3-gram": (cum_bleu_score_3/num_of_rows_calculated),
                "cumulative-4-gram": (cum_bleu_score_4/num_of_rows_calculated)}

    return results

def count_bleu_score(model_count, real_answers, questions):
    preds = []
    for question in questions:
        outputs = model_count.generate(question)
        decoded_output = model_count.dec_tokenizer.decode(outputs[0])
        preds.append(decoded_output)
    return calculate_bleu(preds, questions, real_answers)

# %%
bleu_score_eval = pd.DataFrame(columns=['Epoch', '1-gram', '2-gram', '3-gram', '4-gram', 'cumulative-1-gram', 'cumulative-2-gram', 'cumulative-3-gram', 'cumulative-4-gram'])
bleu_score_train = pd.DataFrame(columns=['Epoch', '1-gram', '2-gram', '3-gram', '4-gram', 'cumulative-1-gram', 'cumulative-2-gram', 'cumulative-3-gram', 'cumulative-4-gram'])

questions = qa_paired_test['Pertanyaan'].apply(lambda x: x.lower().replace('[BOS]', '').replace('[EOS]', '')).to_list()
answers = qa_paired_test['Jawaban'].apply(lambda x: x.replace('[BOS]', '').replace('[EOS]', '').lower().strip()).to_list()
questions_eval = qa_paired_eval['Pertanyaan'].apply(lambda x: x.lower().replace('[BOS]', '').replace('[EOS]', '')).to_list()
answers_eval = qa_paired_eval['Jawaban'].apply(lambda x: x.replace('[BOS]', '').replace('[EOS]', '').lower().strip()).to_list()

epochs = 500
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
criterion = nn.CrossEntropyLoss()

for ep in range(epochs):
    torch.cuda.empty_cache()

    total_loss = 0
    for instance in qa_paired_test.iterrows():
        # print("---------------")
        optimizer.zero_grad()

        pertanyaan = instance[1]['Pertanyaan']
        jawaban = instance[1]['Jawaban']
        jawaban_withpre = '[PRE1][PRE2][PRE3]' + jawaban

        tokenized_jawaban_withpre = model.dec_tokenizer(jawaban_withpre)
        tokenized_jawaban_withpre = torch.tensor(tokenized_jawaban_withpre['input_ids']).unsqueeze(0)

        enc_logits = model.encoding(pertanyaan)
        output = model.decoding_train(enc_logits, target=jawaban, target_with_pre=tokenized_jawaban_withpre)

        loss = output.loss
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

    print(f'Epoch {ep+1}/{epochs} - Loss: {total_loss:.4f}')
    if (ep+1) % 10 == 0:
        print(f'\n-----------------------------------------')
        test_question = qa_paired_test['Pertanyaan'].iloc[0]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        test_question = qa_paired_test['Pertanyaan'].iloc[1]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        test_question = qa_paired_test['Pertanyaan'].iloc[4]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        print(f'-----------------------------------------\n')

    if (ep+1) % 10 == 0:
        bleu_result = count_bleu_score(model, answers_eval, questions_eval)
        bleu_score_eval = pd.concat([bleu_score_eval, pd.DataFrame({'Epoch': ep+1, **bleu_result}, index=[len(bleu_score_eval)])], ignore_index=True)
        print(f'BLEU Score Eval: {bleu_result["cumulative-4-gram"]:.4f}\n')

        bleu_result = count_bleu_score(model, answers, questions)
        bleu_score_train = pd.concat([bleu_score_train, pd.DataFrame({'Epoch': ep+1, **bleu_result}, index=[len(bleu_score_train)])], ignore_index=True)
        print(f'BLEU Score Train: {bleu_result["cumulative-4-gram"]:.4f}\n')
# Out:
# Epoch 1/500 - Loss: 201.1310
# Epoch 2/500 - Loss: 183.4015
# Epoch 3/500 - Loss: 170.9416
# Epoch 4/500 - Loss: 165.4519
# Epoch 5/500 - Loss: 160.0149
# Epoch 6/500 - Loss: 155.3962
# Epoch 7/500 - Loss: 150.5341
# Epoch 8/500 - Loss: 145.4780
# Epoch 9/500 - Loss: 140.5855
# Epoch 10/500 - Loss: 135.8109
#
# -----------------------------------------
# Q >>> visi filkom
# A <<<
# P [PRE1] [PRE2]
# P [PRE1] [PRE2]
# P[SEP][SEP]
# P[SEP][SEP]
# P[SEP][PAD]
# P[BOS]
# P[BOS]
# P[BOS]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P [PRE1]
# P [PRE1]
# P[PAD]
# P[PAD]
# P[PAD]
# P[PAD]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P[BOS]
# P[BOS]
# P[BOS]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P [PRE1]
# P[BOS]
# P[BOS]
# P
# Q >>> misi filkom
# A <<<
# M[SEP][SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][PAD]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[PAD]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[PAD]
# M[SEP]
# M[PAD]:
# M[SEP]
# M[SEP]
# M[SEP]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]:
# M[PAD]
# M[SEP]
# M[SEP]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD].
# M[PAD]
# M[PAD]
# M[PAD]
# M[PAD].
# M
# Q >>> email fitra a. bachtiar
# A <<< .
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[SEP]
# M[PAD]/
# -----------------------------------------
#
# BLEU Score Eval: 0.0003
#
# BLEU Score Train: 0.0005
#
# Epoch 11/500 - Loss: 131.3180
# Epoch 12/500 - Loss: 126.9636
# Epoch 13/500 - Loss: 122.7057
# Epoch 14/500 - Loss: 118.7308
# Epoch 15/500 - Loss: 114.1789
# Epoch 16/500 - Loss: 110.3456
# Epoch 17/500 - Loss: 107.0979
# Epoch 18/500 - Loss: 104.0188
# Epoch 19/500 - Loss: 102.2578
# Epoch 20/500 - Loss: 101.4635
#
# -----------------------------------------
# Q >>> visi filkom
# A <<<
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][SEP]
# M[SEP][PAD]
# M[SEP]
# M[SEP]
# M
# Q >>> misi filkom
# A <<<
# D[SEP] [PRE2]
# D[SEP] [PRE2]
# D[SEP] [PRE2]
# D[SEP]
# Q >>> email fitra a. bachtiar
# A <<< _
# -----------------------------------------
#
# BLEU Score Eval: 0.0017
#
# BLEU Score Train: 0.0031
#
# Epoch 21/500 - Loss: 95.4203
# Epoch 22/500 - Loss: 92.8662
# Epoch 23/500 - Loss: 89.5606
# Epoch 24/500 - Loss: 85.1144
# Epoch 25/500 - Loss: 82.0996
# Epoch 26/500 - Loss: 79.0461
# Epoch 27/500 - Loss: 75.8107
# Epoch 28/500 - Loss: 72.7323
# Epoch 29/500 - Loss: 70.7678
# Epoch 30/500 - Loss: 68.5854
#
# -----------------------------------------
# Q >>> visi filkom
# A <<<
# PENGEMBANGAN MODUL PEMBELAJARAN BERBASIS PENDEKATAN SAINTIFIK PADA MATERI POKOK KEANEKARAGAMAN HAYATI UNTUK SISWA KELAS X SMA
# PENGEMBANGAN MODUL PEMBELAJARAN BERBASIS PENDEKATAN SAINTIFIK PADA MATERI POKOK KEANEKARAGAMAN HAYATI UNTUK SISWA KELAS X SMA
# D[SEP][SEP][SEP][SEP][SEP][SEP][BOS][BOS][BOS][PAD][PAD][PAD][PAD][PAD]
# Q >>> misi filkom
# A <<< , S.T., M.T.P [PRE1], S.T., M.T.P[BOS], S.T., M.T.P[BOS], S.T., M.T.P[BOS], S.T., M.T.P[BOS], S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.T.P, S.
# Q >>> email fitra a. bachtiar
# A <<<  farida.s.t.ika.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.t.i.a.s.
# -----------------------------------------
#
# BLEU Score Eval: 0.0494
#
# BLEU Score Train: 0.0752
#
# Epoch 31/500 - Loss: 67.5479
# Epoch 32/500 - Loss: 63.9040
# Epoch 33/500 - Loss: 60.5947
# Epoch 34/500 - Loss: 58.2838
# Epoch 35/500 - Loss: 56.3990
# Epoch 36/500 - Loss: 54.3066
# Epoch 37/500 - Loss: 52.8706
# Epoch 38/500 - Loss: 50.9764
# Epoch 39/500 - Loss: 48.3909
# Epoch 40/500 - Loss: 46.5593
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi program studi yang unggul dalam bidang manajemen sumber daya manusia yang memiliki kompetensi di bidang manajemen sumber daya manusia yang memiliki daya saing global di bidang manajemen sumber daya manusia pada tahun 2023.
# 1. Menyelenggarakan pendidikan dan pengajaran yang berkualitas untuk menghasilkan lulusan yang memiliki kompetensi di bidang manajemen sumber daya manusia yang memiliki daya saing global.
# 2. Menyelenggarakan penelitian yang berkualitas untuk menghasilkan luaran yang memiliki daya saing global.
# 3. Menyelenggarakan pengabdian masyarakat yang berkualitas untuk menghasilkan luaran yang memiliki daya saing global.
# 4. Menyelenggarakan kerjasama dengan berbagai pihak untuk menghasilkan luaran yang memiliki daya saing global.
# 1. Menyelenggarakan pendidikan dan pengajaran yang berkualitas untuk menghasilkan lulusan yang memiliki kompetensi di bidang manajemen sumber daya manusia yang memiliki daya saing global.
# 2. Menyelenggarakan penelitian yang berkualitas untuk menghasilkan luaran yang memiliki daya saing global.
# 3. Menyelenggarakan pengabdian masyarakat yang berkualitas untuk menghasilkan luaran yang memiliki daya saing global.
# 1. Menyelenggarakan pendidikan dan pengajaran yang berkualitas untuk menghasilkan lulusan yang memiliki kompetensi
# Q >>> misi filkom
# A <<< meningkatkan kualitas hidup masyarakat melalui peningkatan akses terhadap layanan kesehatan yang berkualitas, merata dan terjangkau, serta meningkatkan kualitas hidup manusia Indonesia melalui peningkatan kualitas sumber daya manusia.
# https://dx.doi.org/10.24843/jkk.v2i1.137
# Abstract views : 448 times | PDF files viewed : 441 times
# Copyright (c) 2019[SEP][SEP][SEP][PAD][PAD]
# DOI: https://doi.org/10.24843/jkk.v2i1.137
# Abstract views : 448 times | PDF files viewed : 441 times
# PENGARUH PENERAPAN MODEL PEMBELAJARAN KOOPERATIF TIPE STAD TERHADAP KEMAMPUAN KOMUNIKASI MATEMATIS SISWA KELAS VII SMP NEGERI 1 GEDONG TENGAH TAHUN PELAJARAN 2018
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score Eval: 0.1757
#
# BLEU Score Train: 0.3202
#
# Epoch 41/500 - Loss: 46.4396
# Epoch 42/500 - Loss: 45.5360
# Epoch 43/500 - Loss: 42.8279
# Epoch 44/500 - Loss: 40.7610
# Epoch 45/500 - Loss: 39.7937
# Epoch 46/500 - Loss: 38.0354
# Epoch 47/500 - Loss: 37.8961
# Epoch 48/500 - Loss: 38.4498
# Epoch 49/500 - Loss: 37.3176
# Epoch 50/500 - Loss: 35.6395
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang unggul dalam pengembangan ilmu pengetahuan dan teknologi yang berbasis pada kearifan lokal dan global di bidang ilmu komputer dan informatika yang berorientasi pada kebutuhan masyarakat dan industri di tingkat nasional dan internasional pada tahun2024.
# Menyelenggarakan pendidikan dan pengajaran yang berkualitas untuk menghasilkan lulusan yang memiliki kompetensi di bidang ilmu komputer dan informatika yang memiliki kemampuan akademik dan profesional di bidang ilmu komputer dan informatika yang memiliki kemampuan manajerial dan kepemimpinan yang baik.
# Menyelenggarakan penelitian yang berkualitas untuk menghasilkan karya ilmiah yang bermanfaat bagi masyarakat dan industri.
# Menyelenggarakan pengabdian kepada masyarakat yang berkualitas untuk menghasilkan karya ilmiah yang bermanfaat bagi masyarakat dan industri.
# Menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas pendidikan dan penelitian.
# Menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas pendidikan dan penelitian.
# Menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas pendidikan dan penelitian.
# Menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas pendidikan dan penelitian.
# Menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas pendidikan dan penelitian.
# Menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan
# Q >>> misi filkom
# A <<< untuk meningkatkan kualitas pembelajaran, khususnya dalam mata pelajaran Bahasa Indonesia, maka perlu dilakukan penelitian.Penelitian ini bertujuan untuk meningkatkan kemampuan menulis karangan narasi melalui model pembelajaran kooperatif tipe Think-Pair-Share pada siswa kelas VII-A SMP Negeri 1 [PRE2] [PRE2] [PRE2] [PRE2] [PRE2] [PAD][PAD][BOS][BOS][BOS][BOS][BOS][BOS][BOS][BOS]
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score Eval: 0.3079
#
# BLEU Score Train: 0.5004
#
# Epoch 51/500 - Loss: 33.5198
# Epoch 52/500 - Loss: 31.5839
# Epoch 53/500 - Loss: 30.8151
# Epoch 54/500 - Loss: 29.0240
# Epoch 55/500 - Loss: 27.9667
# Epoch 56/500 - Loss: 26.8814
# Epoch 57/500 - Loss: 26.4149
# Epoch 58/500 - Loss: 26.3143
# Epoch 59/500 - Loss: 25.4908
# Epoch 60/500 - Loss: 24.7322
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang unggul dalam pengembangan ilmu pengetahuan dan teknologi di bidang manajemen dan akuntansi yang berbasis pada nilai-nilai moral dan etika, serta mampu bersaing secara nasional dan internasional di bidang manajemen dan akuntansi pada tahun 2023.
# H[PAD] [PRE1] [PRE2] [BOS][BOS]
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan tinggi yang berkualitas dan relevan dengan kebutuhan pembangunan nasional dan kebutuhan masyarakat, serta menghasilkan lulusan yang memiliki kompetensi dan daya saing tinggi.
# j.	menyelenggarakan penelitian dan pengabdian kepada masyarakat yang berorientasi pada kebutuhan pembangunan nasional dan kebutuhan masyarakat.
# k.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas pendidikan tinggi.
# l.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas penelitian.
# m.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas pengabdian kepada masyarakat.
# n.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas publikasi ilmiah.
# o.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas publikasi ilmiah.
# p.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas publikasi ilmiah.
# q.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas publikasi ilmiah.
# r.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas publikasi ilmiah.
# s.	menyelenggarakan kerjasama dengan berbagai pihak untuk meningkatkan kualitas publikasi ilmiah.
# t.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score Eval: 0.3580
#
# BLEU Score Train: 0.6252
#
# Epoch 61/500 - Loss: 24.6659
# Epoch 62/500 - Loss: 24.4437
# Epoch 63/500 - Loss: 23.8751
# Epoch 64/500 - Loss: 22.9745
# Epoch 65/500 - Loss: 22.3805
# Epoch 66/500 - Loss: 21.8218
# Epoch 67/500 - Loss: 20.7231
# Epoch 68/500 - Loss: 20.1213
# Epoch 69/500 - Loss: 19.5547
# Epoch 70/500 - Loss: 19.6128
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi terhadap pembangunan nasional melalui pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan tinggi yang berkualitas dan menghasilkan lulusan yang memiliki kemampuan dalam bidang ilmu pengetahuan dan teknologi, serta memiliki daya saing yang tinggi dalam masyarakat pada tingkat nasional dan internasional.
# weny[SEP][SEP]
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score Eval: 0.3609
#
# BLEU Score Train: 0.6851
#
# Epoch 71/500 - Loss: 19.4785
# Epoch 72/500 - Loss: 18.8458
# Epoch 73/500 - Loss: 19.7330
# Epoch 74/500 - Loss: 19.0965
# Epoch 75/500 - Loss: 18.4815
# Epoch 76/500 - Loss: 18.3372
# Epoch 77/500 - Loss: 19.2539
# Epoch 78/500 - Loss: 20.7241
# Epoch 79/500 - Loss: 20.9645
# Epoch 80/500 - Loss: 22.7069
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< meningkatkan kualitas hidup manusia melalui peningkatan aksesibilitas layanan keuangan, meningkatkan efisiensi ekonomi dan daya saing, serta mendorong pertumbuhan ekonomi yang berkelanjutan.
# wirausaha, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan, kewirausahaan
# Q >>> misi filkom
# A <<< dalam upaya meningkatkan kualitas dan kuantitas tridharma perguruan tinggi, Direktorat Jenderal Pembelajaran dan Kemahasiswaan Kementerian Riset, Teknologi, dan Pendidikan Tinggi menyelenggarakan kegiatan Pelatihan Peningkatan Kompetensi Tenaga Pendidik dan Tenaga Kependidikan Bidang TIK pada Perguruan Tinggi.
# Kegiatan ini bertujuan untuk meningkatkan kompetensi tenaga pendidik dan tenaga kependidikan bidang TIK pada perguruan tinggi.
# Kegiatan ini diikuti oleh sebanyak 20 orang peserta yang berasal dari perguruan tinggi negeri dan swasta di wilayah Kopertis Wilayah I s.d. XIV.
# Kegiatan ini dibuka oleh Kepala Bidang Pembinaan Pendidik dan Tenaga Kependidikan, Dr. [PRE2] [PRE2]  salah satu tenaga pendidik dan
# Kegiatan pelatihan ini merupakan salah satu tenaga pendidik dan tenaga pendidik yang bekerja di perguruan tinggi yang memiliki tenaga pendidik dan tenaga pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki sertifikasi pendidik yang telah memiliki
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score Eval: 0.2744
#
# BLEU Score Train: 0.5219
#
# Epoch 81/500 - Loss: 23.1250
# Epoch 82/500 - Loss: 18.9645
# Epoch 83/500 - Loss: 16.1360
# Epoch 84/500 - Loss: 14.9766
# Epoch 85/500 - Loss: 14.1581
# Epoch 86/500 - Loss: 13.3280
# Epoch 87/500 - Loss: 12.6801
# Epoch 88/500 - Loss: 12.2844
# Epoch 89/500 - Loss: 11.7439
# Epoch 90/500 - Loss: 11.3848
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional.
# meningkatkan kualitas sumber daya manusia melalui penelitian dan publikasi ilmiah yang bertaraf internasional.
# menyelenggarakan pengabdian kepada masyarakat dalam bidang teknologi informasi dan ilmu komputer.
# menyelenggarakan penelitian yang berorientasi pada pengembangan teknologi informasi dan ilmu komputer.
# menyelenggarakan pengabdian kepada masyarakat dalam bidang teknologi informasi dan ilmu komputer.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score Eval: 0.4210
#
# BLEU Score Train: 0.7884
#
# Epoch 91/500 - Loss: 11.1402
# Epoch 92/500 - Loss: 10.9647
# Epoch 93/500 - Loss: 10.6691
# Epoch 94/500 - Loss: 10.3045
# Epoch 95/500 - Loss: 10.1683
# Epoch 96/500 - Loss: 9.6453
# Epoch 97/500 - Loss: 9.3855
# Epoch 98/500 - Loss: 9.1896
# Epoch 99/500 - Loss: 8.8878
# Epoch 100/500 - Loss: 8.9816
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional, yang tanggap, kritis, dan mampu menjawab kebutuhan pasar, serta menghasilkan lulusan yang berdaya saing internasional.
# mewujudkan penelitian yang berorientasi pada pengembangan teknologi informasi dan ilmu komputer yang bermanfaat bagi masyarakat, bangsa, dan negara.
# mewujudkan pengabdian kepada masyarakat yang berorientasi pada pengembangan teknologi informasi dan ilmu komputer yang bermanfaat bagi masyarakat, bangsa, dan negara.
# mewujudkan kerjasama di bidang penelitian dan pengabdian kepada masyarakat dalam rangka mendukung pengembangan teknologi informasi dan ilmu komputer.
# mewujudkan tata kelola organisasi yang baik (good governance) dalam rangka meningkatkan kualitas penyelenggaraan pendidikan, penelitian, dan pengabdian kepada masyarakat.
# Q >>> email fitra a. bachtiar
# A <<<  fitra.bachtiar[at]ub.ac.id
# -----------------------------------------
#
# BLEU Score Eval: 0.4191
#
# BLEU Score Train: 0.8016
#
# Epoch 101/500 - Loss: 8.7541
# Epoch 102/500 - Loss: 8.6465
# Epoch 103/500 - Loss: 8.7269
# Epoch 104/500 - Loss: 8.6528
# Epoch 105/500 - Loss: 8.2433
# Epoch 106/500 - Loss: 7.7110
# Epoch 107/500 - Loss: 7.2475
# Epoch 108/500 - Loss: 6.9516
# Epoch 109/500 - Loss: 6.8848
# Epoch 110/500 - Loss: 6.3981
#
# -----------------------------------------
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional yang dapat menghasilkan lulusan yang berdaya saing internasional serta mampu memenuhi kebutuhan pasar dalam menyongsong era globalisasi.
# memenuhi kebutuhan masyarakat dalam bidang teknologi informasi dan ilmu komputer yang dapat dimanfaatkan untuk meningkatkan kualitas hidup dan kesejahteraan masyarakat.
# memenuhi kebutuhan masyarakat dalam bidang teknologi informasi dan ilmu komputer yang dapat dimanfaatkan untuk meningkatkan kualitas hidup dan kesejahteraan masyarakat.
# memenuhi kebutuhan masyarakat dalam bidang teknologi informasi dan ilmu komputer yang dapat dimanfaatkan untuk meningkatkan kualitas hidup dan kesejahteraan masyarakat.
# memenuhi kebutuhan masyarakat dalam bidang teknologi informasi dan ilmu komputer yang dapat dimanfaatkan untuk meningkatkan kualitas hidup dan kesejahteraan masyarakat.
# memenuhi kebutuhan masyarakat dalam bidang teknologi informasi dan ilmu komputer yang dapat dimanfaatkan untuk meningkatkan kualitas hidup dan kesejahteraan masyarakat.
# memenuhi kebutuhan masyarakat dalam bidang teknologi informasi dan ilmu komputer yang dapat dimanfaatkan untuk meningkatkan kualit
gram')
plt.plot(bleu_score_train['Epoch'], bleu_score_train['cumulative-3-gram'], label='Train cumulative-3-gram')
plt.plot(bleu_score_train['Epoch'], bleu_score_train['cumulative-4-gram'], label='Train cumulative-4-gram')
plt.xlabel('Epoch')
plt.ylabel('BLEU Score')
plt.ylim(0, 1)
plt.title('BLEU Score on 3 PRE Token')
# make legend smaller
plt.legend(fontsize='small')
# add number for each 100 epoch

# %%
# get best 4-cumulative-gram row, outuput eppoch and other score
best_row = bleu_score_eval.loc[bleu_score_eval['cumulative-4-gram'].idxmax()]
best_epoch = best_row['Epoch']
best_score = best_row['cumulative-4-gram']
print(f'Best BLEU Score on Eval: {best_score:.4f} at Epoch {best_epoch}')
train_score = bleu_score_train.loc[bleu_score_train['Epoch'] == best_epoch]
print(f'Train Score: {train_score["cumulative-4-gram"].values[0]:.4f}')
# Out:
# Best BLEU Score on Eval: 0.7354 at Epoch 270
# Train Score: 0.9680

# %%
test_question = "fitra bachtiar penelitian apa "
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> fitra bachtiar penelitian apa
# A <<< affective computing, affective engineering, intelligent system, data mining, educational data mining

# %%
test_question = "ketua bpj teh saha ieu"
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> ketua bpj teh saha ieu
# A <<< berlaku penuhantiemayoto, s.t., m.t.

# %%
test_question = "kepala program studi sarjana sistem informasi teh saha"
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> kaprodi sarjana sistem informasi teh saha
# A <<<  sk dikti no.163/kep/dikti/2007

# %%
for i in range(len(qa_paired_eval)):
    test_question = qa_paired_eval['Pertanyaan'].iloc[i]
    outputs = model.generate(test_question)
    decoded_output = model.dec_tokenizer.decode(outputs[0])
    qa_paired_eval.loc[i, 'Predicted Answer'] = decoded_output

# %%
qa_paired_eval
# Out:
#                                           Pertanyaan  \
# 0                                  apa visi fakultas
# 1                                  visi dari filkokm
# 2                               apa saja visi filkom
# 3                                  apa misi fakultas
# 4                                apa saja misi flkom
# ..                                               ...
# 69                      apa manfaat konseling filkom
# 70      berikan informasi mengenai layanan konseling
# 71  siapa konselor bimbingan dan konseling di filkom
# 72                 siapa koordinator konselor sebaya
# 73                    berikan rincian layanan ultksp
#
#                                               Jawaban  \
# 0   menjadi fakultas yang berdaya saing internasio...
# 1   menjadi fakultas yang berdaya saing internasio...
# 2   menjadi fakultas yang berdaya saing internasio...
# 3   menyelenggarakan pendidikan di bidang teknolog...
# 4   menyelenggarakan pendidikan di bidang teknolog...
# ..                                                ...
# 69  1. masalah ditangani oleh ahli yang kompeten d...
# 70  informasi mengenai layanan konseling dapat dia...
# 71  ada 2 konselor bimbingan dan konseling di filk...
# 72  koordinator konselor sebaya adalah muhammad da...
# 73  rincian layanan ultksp dapat diakses pada taut...
#
#                                      Predicted Answer
# 0   1. mewujudkan potensi dirinya secara optimal, ...
# 1   menjadi fakultas yang berdaya saing internasio...
# 2   menghasilkan lulusan yang kompeten, profesiona...
# 3   1. mewujudkan potensi dirinya secara optimal, ...
# 4   menghasilkan lulusan yang kompeten, profesiona...
# ..                                                ...
# 69  1. masalah ditangani oleh ahli yang kompeten d...
# 70  informasi mengenai layanan konseling dapat dia...
# 71  ada 2 konselor bimbingan dan konseling di filk...
# 72  koordinator konselor sebaya adalah muhammad da...
# 73  rincian layanan ultksp dapat diakses pada taut...
#
# [74 rows x 3 columns]

# %%
torch.save(model.state_dict(), 'FLUENTSOTA_091024_3PRE.pth')

# %%
qa_paired_eval.to_excel('qa_paired_eval_091024_3PRE.xlsx', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
