# %%
# !nvidia-smi
# Out:
# Fri Oct  4 18:34:58 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   37C    P0   109W / 400W |  33304MiB / 81251MiB |     62%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from transformers import AutoTokenizer, AutoModel, GPT2LMHeadModel, GPT2Tokenizer
from sklearn.decomposition import PCA
from torch import nn
import torch
import matplotlib.pyplot as plt
import time
import pandas as pd

# %%
knowledgebase_url = 'https://github.com/AndiAlifs/FLUENT-Chatbot-2023/raw/main/KnowledgeBaseFilkom.xlsx'
# knowledgebase_url = 'https://github.com/AndiAlifs/FLUENT-Chatbot-2023/raw/main/KnowledgeBaseFilkom_simple.xlsx'
knowledgebase = pd.read_excel(knowledgebase_url)

qa_paired = knowledgebase.drop(columns=knowledgebase.columns.drop(['Pertanyaan', 'Jawaban']))
qa_paired.dropna(inplace=True)
qa_paired
# Out:
#                                              Pertanyaan  \
# 0                               email Fitra A. Bachtiar
# 1                             NIK/NIP Fitra A. Bachtiar
# 2                        nama lengkap Fitra A. Bachtiar
# 3                          Departemen Fitra A. Bachtiar
# 4                       Program Studi Fitra A. Bachtiar
# ...                                                 ...
# 1229                     Apa Manfaat Konseling FILKOM ?
# 1230       Berikan informasi mengenai Layanan Konseling
# 1231  Siapa Konselor Bimbingan dan Konseling di FILK...
# 1232                Siapa Koordinator Konselor Sebaya ?
# 1233                     Berikan Rincian Layanan ULTKSP
#
#                                                 Jawaban
# 0                            fitra.bachtiar[at]ub.ac.id
# 1                                    198406282019031006
# 2                             Dr.Eng. Fitra A. Bachtiar
# 3                         Departemen Teknik Informatika
# 4                                      S2 Ilmu Komputer
# ...                                                 ...
# 1229  1. Masalah ditangani oleh ahli yang kompeten d...
# 1230  Informasi mengenai Layanan Konseling dapat dia...
# 1231  Ada 2 konselor Bimbingan dan Konseling di FILK...
# 1232  Koordinator Konselor Sebaya adalah Muhammad Da...
# 1233  Rincian Layanan ULTKSP dapat diakses pada taut...
#
# [1198 rows x 2 columns]

# %%
enc_tokenizer = AutoTokenizer.from_pretrained('firqaaa/indo-sentence-bert-base')
enc_model = AutoModel.from_pretrained('firqaaa/indo-sentence-bert-base')
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# model_name_dec = 'flax-community/gpt2-medium-indonesian'
model_name_dec = 'indonesian-nlp/gpt2-medium-indonesian'

dec_model = GPT2LMHeadModel.from_pretrained(model_name_dec)
dec_tokenizer = GPT2Tokenizer.from_pretrained(model_name_dec)

dec_tokenizer.add_tokens(['[PRE1]'])
dec_tokenizer.add_tokens(['[PRE2]'])
dec_tokenizer.add_tokens(['[PRE3]'])
dec_tokenizer.add_tokens(['[PRE4]'])
dec_tokenizer.add_tokens(['[PRE5]'])

dec_tokenizer.add_special_tokens({'pad_token': '[PAD]',
                                    'bos_token': '[BOS]',
                                    'eos_token': '[EOS]',
                                    'sep_token': '[SEP]',})

# Add a new token to the tokenizer
dec_model.config.pad_token_id = dec_tokenizer.pad_token_id
dec_model.config.bos_token_id = dec_tokenizer.bos_token_id
dec_model.config.eos_token_id = dec_tokenizer.eos_token_id
dec_model.config.sep_token_id = dec_tokenizer.sep_token_id

dec_model.resize_token_embeddings(len(dec_tokenizer))
# Out:
# Embedding(50266, 1024)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
enc_model = enc_model.to(device)
dec_model = dec_model.to(device)

# %%
qa_paired_test = qa_paired[:40]
qa_paired_test = qa_paired_test.applymap(lambda x: x.lower() if isinstance(x, str) else x)
qa_paired_test['Jawaban'] = qa_paired_test['Jawaban'].apply(lambda x: '[BOS]' + x + '[EOS]')
qa_paired_test['JawabanWithPre'] = qa_paired_test['Jawaban'].apply(lambda x: '[PRE1][PRE2][PRE3]' + x)
qa_paired_test = qa_paired_test.reset_index(drop=True)
qa_paired_test
# Out:
#                                            Pertanyaan  \
# 0                             email fitra a. bachtiar
# 1                           nik/nip fitra a. bachtiar
# 2                      nama lengkap fitra a. bachtiar
# 3                        departemen fitra a. bachtiar
# 4                     program studi fitra a. bachtiar
# 5                 bidang penelitian fitra a. bachtiar
# 6           nama awal fakultas ilmu komputer (filkom)
# 7     rujukan surat keputusan sk dikti dibentuk ptiik
# 8              surat keputusan sk rektor bentuk ptiik
# 9                              tanggal dibentuk ptiik
# 10                      program studi pembentuk ptiik
# 11             tanggal perubahan ptiik menjadi filkom
# 12                    surat keputusan sk dikti filkom
# 13                                        visi filkom
# 14                                        misi filkom
# 15                                 apa tujuan filkom?
# 16                          sasaran pendidikan filkom
# 17                          sasaran penelitian filkom
# 18                          sasaran pengabdian filkom
# 19                           sasaran kerjasama filkom
# 20                dekan fakultas ilmu komputer filkom
# 21        wakil dekan bidang akademik / wakil dekan 1
# 22  wakil dekan bidang umum, keuangan, dan sumber ...
# 23  wakil dekan bidang kemahasiswaan, alumni, dan ...
# 24                ketua departemen teknik informatika
# 25           sekretaris departemen teknik informatika
# 26         ketua program studi magister ilmu komputer
# 27     ketua program studi sarjana teknik informatika
# 28        ketua program studi sarjana teknik komputer
# 29                  ketua departemen sistem informasi
# 30              seketaris departemen sistem informasi
# 31       ketua program studi sarjana sistem informasi
# 32  ketua program studi sarjana pendidikan teknolo...
# 33    ketua program studi sarjana teknologi informasi
# 34                ketua badan penerbitan jurnal (bpj)
# 35  ketua unit pengelola sistem informasi dan kehu...
# 36  sekretaris unit pengelola sistem informasi dan...
# 37  ketua badan penelitian dan pengabdian kepada m...
# 38  sekretaris badan penelitian dan pengabdian kep...
# 39          ketua unit peningkatan kompetensi profesi
#
#                                               Jawaban  \
# 0               [BOS] fitra.bachtiar[at]ub.ac.id[EOS]
# 1                        [BOS]198406282019031006[EOS]
# 2                 [BOS]dr.eng. fitra a. bachtiar[EOS]
# 3             [BOS]departemen teknik informatika[EOS]
# 4                          [BOS]s2 ilmu komputer[EOS]
# 5   [BOS]affective computing, affective engineerin...
# 6   [BOS]program teknologi informasi dan ilmu komp...
# 7          [BOS] sk dikti no.163/kep/dikti/2007 [EOS]
# 8   [BOS]surat keputusan rektor universitas brawij...
# 9                           [BOS]27 oktober 2011[EOS]
# 10  [BOS]teknik perangkat lunak dari fakultas tekn...
# 11                         [BOS]10 desember 2014[EOS]
# 12  [BOS]surat dikti no. 8073/ei/ot/2014 tentang o...
# 13  [BOS]menjadi fakultas yang berdaya saing inter...
# 14  [BOS]menyelenggarakan pendidikan di bidang tek...
# 15  [BOS]menghasilkan lulusan yang kompeten , prof...
# 16  [BOS]1. meningkatkan kompetensi dan kualifikas...
# 17  [BOS]1. meningkatkan jumlah publikasi ilmiah\n...
# 18  [BOS]1. meningkatkan kualitas dan kuantitas pe...
# 19  [BOS]1. mengadakan kerjasama pendidikan, penli...
# 20  [BOS]prof. ir. wayan firdaus mahmudy, s.si., m...
# 21      [BOS]dr. eng. ir. herman tolle, st., mt.[EOS]
# 22            [BOS]agus wahyu widodo, st., m.cs.[EOS]
# 23            [BOS]drs. muh. arif rahman, m.kom.[EOS]
# 24        [BOS]achmad basuki, s.t., m.mg., ph.d.[EOS]
# 25     [BOS]ir. primantara hari trisnawan, m.sc.[EOS]
# 26  [BOS]sabriansyah rizqika akbar, s.t., m.eng., ...
# 27         [BOS]adhitya bhawiyuga, s.kom., m.sc.[EOS]
# 28  [BOS]barlian henryranu prasetio, s.t., m.t., p...
# 29               [BOS]issa arwani, s.kom., m.sc.[EOS]
# 30    [BOS]satrio agung wicaksono, s.kom., m.kom[EOS]
# 31       [BOS]yusi tyroni mursityo, s.kom., m.s.[EOS]
# 32  [BOS]ir. admaja dwi herlambang, s.pd., m.pd.[EOS]
# 33  [BOS]ir. widhy hayuhardhika nugraha putra, s.k...
# 34  [BOS]agung setia budi, s.t., m.t., m.eng., ph....
# 35               [BOS]dahnial syauqy, s.t., m.t.[EOS]
# 36             [BOS]fais al huda, s.kom., m.kom.[EOS]
# 37                [BOS]bayu rahayudi, s.t., m.t.[EOS]
# 38            [BOS]faizatul amalia, s.pd., m.pd.[EOS]
# 39                [BOS]tri afirianto, s.t., m.t.[EOS]
#
#                                        JawabanWithPre
# 0   [PRE1][PRE2][PRE3][BOS] fitra.bachtiar[at]ub.a...
# 1      [PRE1][PRE2][PRE3][BOS]198406282019031006[EOS]
# 2   [PRE1][PRE2][PRE3][BOS]dr.eng. fitra a. bachti...
# 3   [PRE1][PRE2][PRE3][BOS]departemen teknik infor...
# 4        [PRE1][PRE2][PRE3][BOS]s2 ilmu komputer[EOS]
# 5   [PRE1][PRE2][PRE3][BOS]affective computing, af...
# 6   [PRE1][PRE2][PRE3][BOS]program teknologi infor...
# 7   [PRE1][PRE2][PRE3][BOS] sk dikti no.163/kep/di...
# 8   [PRE1][PRE2][PRE3][BOS]surat keputusan rektor ...
# 9         [PRE1][PRE2][PRE3][BOS]27 oktober 2011[EOS]
# 10  [PRE1][PRE2][PRE3][BOS]teknik perangkat lunak ...
# 11       [PRE1][PRE2][PRE3][BOS]10 desember 2014[EOS]
# 12  [PRE1][PRE2][PRE3][BOS]surat dikti no. 8073/ei...
# 13  [PRE1][PRE2][PRE3][BOS]menjadi fakultas yang b...
# 14  [PRE1][PRE2][PRE3][BOS]menyelenggarakan pendid...
# 15  [PRE1][PRE2][PRE3][BOS]menghasilkan lulusan ya...
# 16  [PRE1][PRE2][PRE3][BOS]1. meningkatkan kompete...
# 17  [PRE1][PRE2][PRE3][BOS]1. meningkatkan jumlah ...
# 18  [PRE1][PRE2][PRE3][BOS]1. meningkatkan kualita...
# 19  [PRE1][PRE2][PRE3][BOS]1. mengadakan kerjasama...
# 20  [PRE1][PRE2][PRE3][BOS]prof. ir. wayan firdaus...
# 21  [PRE1][PRE2][PRE3][BOS]dr. eng. ir. herman tol...
# 22  [PRE1][PRE2][PRE3][BOS]agus wahyu widodo, st.,...
# 23  [PRE1][PRE2][PRE3][BOS]drs. muh. arif rahman, ...
# 24  [PRE1][PRE2][PRE3][BOS]achmad basuki, s.t., m....
# 25  [PRE1][PRE2][PRE3][BOS]ir. primantara hari tri...
# 26  [PRE1][PRE2][PRE3][BOS]sabriansyah rizqika akb...
# 27  [PRE1][PRE2][PRE3][BOS]adhitya bhawiyuga, s.ko...
# 28  [PRE1][PRE2][PRE3][BOS]barlian henryranu prase...
# 29  [PRE1][PRE2][PRE3][BOS]issa arwani, s.kom., m....
# 30  [PRE1][PRE2][PRE3][BOS]satrio agung wicaksono,...
# 31  [PRE1][PRE2][PRE3][BOS]yusi tyroni mursityo, s...
# 32  [PRE1][PRE2][PRE3][BOS]ir. admaja dwi herlamba...
# 33  [PRE1][PRE2][PRE3][BOS]ir. widhy hayuhardhika ...
# 34  [PRE1][PRE2][PRE3][BOS]agung setia budi, s.t.,...
# 35  [PRE1][PRE2][PRE3][BOS]dahnial syauqy, s.t., m...
# 36  [PRE1][PRE2][PRE3][BOS]fais al huda, s.kom., m...
# 37  [PRE1][PRE2][PRE3][BOS]bayu rahayudi, s.t., m....
# 38  [PRE1][PRE2][PRE3][BOS]faizatul amalia, s.pd.,...
# 39  [PRE1][PRE2][PRE3][BOS]tri afirianto, s.t., m....

# %%
class FLUENTSOTA(nn.Module):
    def __init__(self, enc_model, dec_model, enc_tokenizer, dec_tokenizer, max_length=200):
        super(FLUENTSOTA, self).__init__()
        self.enc_model = enc_model
        self.dec_model = dec_model
        self.enc_tokenizer = enc_tokenizer
        self.dec_tokenizer = dec_tokenizer
        self.enc_mapper = nn.Linear(768, 1024)
        self.enc_mapper2 = nn.Linear(1024, 1024)
        self.prefix_nn = nn.Linear(1024, 1024)
        self.prefix_nn2 = nn.Linear(1024, 1024)
        self.prefix_nn3 = nn.Linear(1024, 1024)
        self.prefix_nn4 = nn.Linear(1024, 1024)
        self.prefix_nn5 = nn.Linear(1024, 1024)
        self.max_length = max_length
    
    def encoding(self, sentence):
        tokens = self.enc_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        tokens = tokens.to(device)
        with torch.no_grad():
            output = self.enc_model(**tokens)
        enc_logits = output.last_hidden_state.mean(dim=1)
        enc_logits = self.enc_mapper(enc_logits).to(device)
        enc_logits = self.enc_mapper2(enc_logits).to(device)
        return enc_logits

    def get_embedding(self, sentence):
        tokens = self.dec_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        tokens = tokens.to(device)
        wte = self.dec_model.get_input_embeddings()
        return wte(tokens['input_ids'])

    def dec_tokenizer(self, sentence):
        tokens = self.dec_tokenizer(sentence, return_tensors='pt', padding=True, truncation=True, max_length=self.max_length)
        return tokens

    def add_prefix(self, enc_logits):
        prefix_1 = self.prefix_nn(enc_logits)
        prefix_2 = self.prefix_nn2(enc_logits)
        prefix_3 = self.prefix_nn3(enc_logits)
        prefix_4 = self.prefix_nn4(enc_logits)
        prefix_5 = self.prefix_nn5(enc_logits)

        prefixs = torch.stack((prefix_1, prefix_2, prefix_3, prefix_4, prefix_5), dim=1)
        return prefixs

    def decoding(self, enc_logits, target):
        prefixs = self.add_prefix(enc_logits)
        embed = self.get_embedding(target)
        pref_with_embed = torch.cat((prefixs, embed), dim=1)
        output = self.dec_model(inputs_embeds=pref_with_embed)
        return output

    def decoding_train(self, enc_logits, target, target_with_pre):
        prefixs = self.add_prefix(enc_logits)
        embed = self.get_embedding(target)
        pref_with_embed = torch.cat((prefixs, embed), dim=1)
        output = self.dec_model(inputs_embeds=pref_with_embed, labels=target_with_pre)
        return output

    def generate(self, quest):
        enc_logits = self.encoding(quest)
        prefix_se = '[PRE1][PRE2][PRE3][PRE4][PRE5][BOS]'
        prefix_dec_embed = self.get_embedding(prefix_se)
        prefixs = self.add_prefix(enc_logits)
        
        pref_with_embed = torch.cat((prefixs, prefix_dec_embed), dim=1)

        output = self.dec_model.generate(   inputs_embeds=pref_with_embed, 
                                            max_length=self.max_length, 
                                            pad_token_id=self.dec_model.config.eos_token_id)
        returned_output = []
        for i in range(len(output[0])):
            if output[0][i] != self.dec_model.config.eos_token_id:
                returned_output.append(output[0][i])
            else:
                break
        return torch.tensor(returned_output).unsqueeze(0)

# %%
for param in enc_model.parameters():
    param.requires_grad = False

for param in dec_model.parameters():
    param.requires_grad = False

for param in dec_model.transformer.h[:-15].parameters():
    param.requires_grad = True

for param in enc_model.encoder.layer[:-15].parameters():
    param.requires_grad = True

# %%
model = FLUENTSOTA(enc_model, dec_model, enc_tokenizer, dec_tokenizer)
model.to(device)
# Out:
# FLUENTSOTA(
#   (enc_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(50000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dec_model): GPT2LMHeadModel(
#     (transformer): GPT2Model(
#       (wte): Embedding(50266, 1024)
#       (wpe): Embedding(1024, 1024)
#       (drop): Dropout(p=0.0, inplace=False)
#       (h): ModuleList(
#         (0): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (9): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (10): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (11): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (12): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (13): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (14): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (15): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (16): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (17): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (18): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (19): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (20): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (21): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (22): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (23): GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (lm_head): Linear(in_features=1024, out_features=50266, bias=False)
#   )
#   (enc_mapper): Linear(in_features=768, out_features=1024, bias=True)
#   (enc_mapper2): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn2): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn3): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn4): Linear(in_features=1024, out_features=1024, bias=True)
#   (prefix_nn5): Linear(in_features=1024, out_features=1024, bias=True)
# )

# %%
all_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
untrainable_params = all_params - trainable_params

print(f'All parameters: {all_params:,}')
print(f'Trainable parameters: {trainable_params:,} ({trainable_params/all_params*100:.2f}%)')
print(f'Untrainable parameters: {untrainable_params:,} ({untrainable_params/all_params*100:.2f}%)')
# Out:
# All parameters: 486,358,784
# Trainable parameters: 120,451,072 (24.77%)
# Untrainable parameters: 365,907,712 (75.23%)

# %%
# pertanyaan = qa_paired_test['Pertanyaan'][:20]
# jawaban = qa_paired_test['Jawaban'][:20]
# jawaban_withpre = qa_paired_test['JawabanWithPre'][:20]

# tokenized_jawaban_withpre = model.dec_tokenizer(jawaban_withpre)
# tokenized_jawaban_withpre = torch.tensor(tokenized_jawaban_withpre['input_ids']).unsqueeze(0)

# enc_logits = model.encoding(pertanyaan)
# # print(enc_logits)
# # print(jawaban)
# # print(tokenized_jawaban_withpre)
# output = model.decoding_train(enc_logits, target=jawaban, target_with_pre=tokenized_jawaban_withpre)

# %%
epochs = 500
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()


for ep in range(epochs):
    torch.cuda.empty_cache()

    total_loss = 0
    for instance in qa_paired_test.iterrows():
        # print("---------------")
        optimizer.zero_grad()

        pertanyaan = instance[1]['Pertanyaan']
        jawaban = instance[1]['Jawaban']
        jawaban_withpre = '[PRE1][PRE2][PRE3][PRE4][PRE5]' + jawaban

        tokenized_jawaban_withpre = model.dec_tokenizer(jawaban_withpre)
        tokenized_jawaban_withpre = torch.tensor(tokenized_jawaban_withpre['input_ids']).unsqueeze(0)

        enc_logits = model.encoding(pertanyaan)
        output = model.decoding_train(enc_logits, target=jawaban, target_with_pre=tokenized_jawaban_withpre)

        loss = output.loss
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

    print(f'Epoch {ep+1}/{epochs} - Loss: {total_loss:.4f}')
    if (ep+1) % 10 == 0:
        print(f'\n-----------------------------------------')
        test_question = qa_paired_test['Pertanyaan'].iloc[21]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        test_question = qa_paired_test['Pertanyaan'].iloc[13]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        test_question = qa_paired_test['Pertanyaan'].iloc[14]
        outputs = model.generate(test_question)
        decoded_output = model.dec_tokenizer.decode(outputs[0])
        print(f'Q >>> {test_question}')
        print(f'A <<< {decoded_output}')
        print(f'-----------------------------------------\n')
# Out:
# Epoch 1/500 - Loss: 26.6744
# Epoch 2/500 - Loss: 18.8848
# Epoch 3/500 - Loss: 13.1225
# Epoch 4/500 - Loss: 8.4505
# Epoch 5/500 - Loss: 5.9533
# Epoch 6/500 - Loss: 5.6249
# Epoch 7/500 - Loss: 8.8222
# Epoch 8/500 - Loss: 5.7409
# Epoch 9/500 - Loss: 4.3276
# Epoch 10/500 - Loss: 4.2569
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< ilmu komputer dari ichsan l [PRE5] kilanjt. informatika muh. arif rahman, s.kom., m.kom.
# -----------------------------------------
#
# Epoch 11/500 - Loss: 3.0025
# Epoch 12/500 - Loss: 3.4395
# Epoch 13/500 - Loss: 2.8159
# Epoch 14/500 - Loss: 2.3163
# Epoch 15/500 - Loss: 1.5762
# Epoch 16/500 - Loss: 1.3541
# Epoch 17/500 - Loss: 1.9894
# Epoch 18/500 - Loss: 1.9901
# Epoch 19/500 - Loss: 1.5253
# Epoch 20/500 - Loss: 1.5410
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 21/500 - Loss: 2.1426
# Epoch 22/500 - Loss: 3.7009
# Epoch 23/500 - Loss: 5.3492
# Epoch 24/500 - Loss: 4.5259
# Epoch 25/500 - Loss: 4.8352
# Epoch 26/500 - Loss: 3.7158
# Epoch 27/500 - Loss: 3.7733
# Epoch 28/500 - Loss: 3.1250
# Epoch 29/500 - Loss: 2.2821
# Epoch 30/500 - Loss: 2.6581
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 31/500 - Loss: 2.1590
# Epoch 32/500 - Loss: 0.9118
# Epoch 33/500 - Loss: 1.0042
# Epoch 34/500 - Loss: 0.9906
# Epoch 35/500 - Loss: 0.3374
# Epoch 36/500 - Loss: 0.2657
# Epoch 37/500 - Loss: 0.3151
# Epoch 38/500 - Loss: 0.2911
# Epoch 39/500 - Loss: 0.2438
# Epoch 40/500 - Loss: 0.2032
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 41/500 - Loss: 0.1905
# Epoch 42/500 - Loss: 0.1943
# Epoch 43/500 - Loss: 0.2250
# Epoch 44/500 - Loss: 0.2346
# Epoch 45/500 - Loss: 0.1797
# Epoch 46/500 - Loss: 0.1448
# Epoch 47/500 - Loss: 0.1410
# Epoch 48/500 - Loss: 0.1295
# Epoch 49/500 - Loss: 0.1270
# Epoch 50/500 - Loss: 0.1078
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 51/500 - Loss: 0.1252
# Epoch 52/500 - Loss: 0.1273
# Epoch 53/500 - Loss: 0.1255
# Epoch 54/500 - Loss: 0.0934
# Epoch 55/500 - Loss: 0.0895
# Epoch 56/500 - Loss: 0.0965
# Epoch 57/500 - Loss: 0.1254
# Epoch 58/500 - Loss: 0.1076
# Epoch 59/500 - Loss: 0.0809
# Epoch 60/500 - Loss: 0.0744
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 61/500 - Loss: 0.0999
# Epoch 62/500 - Loss: 0.1320
# Epoch 63/500 - Loss: 0.1241
# Epoch 64/500 - Loss: 0.0729
# Epoch 65/500 - Loss: 0.0673
# Epoch 66/500 - Loss: 0.0624
# Epoch 67/500 - Loss: 0.0941
# Epoch 68/500 - Loss: 0.1619
# Epoch 69/500 - Loss: 0.1169
# Epoch 70/500 - Loss: 0.0756
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 71/500 - Loss: 0.1253
# Epoch 72/500 - Loss: 0.1102
# Epoch 73/500 - Loss: 0.0983
# Epoch 74/500 - Loss: 0.0756
# Epoch 75/500 - Loss: 0.0754
# Epoch 76/500 - Loss: 0.0760
# Epoch 77/500 - Loss: 0.0980
# Epoch 78/500 - Loss: 0.0820
# Epoch 79/500 - Loss: 0.0643
# Epoch 80/500 - Loss: 0.0848
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 81/500 - Loss: 0.1261
# Epoch 82/500 - Loss: 0.0981
# Epoch 83/500 - Loss: 0.0562
# Epoch 84/500 - Loss: 0.0966
# Epoch 85/500 - Loss: 0.1598
# Epoch 86/500 - Loss: 0.1013
# Epoch 87/500 - Loss: 0.0568
# Epoch 88/500 - Loss: 0.0534
# Epoch 89/500 - Loss: 0.1580
# Epoch 90/500 - Loss: 0.0975
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 91/500 - Loss: 0.1249
# Epoch 92/500 - Loss: 0.0809
# Epoch 93/500 - Loss: 0.0559
# Epoch 94/500 - Loss: 0.0552
# Epoch 95/500 - Loss: 0.1110
# Epoch 96/500 - Loss: 0.1250
# Epoch 97/500 - Loss: 0.0989
# Epoch 98/500 - Loss: 0.0473
# Epoch 99/500 - Loss: 0.0419
# Epoch 100/500 - Loss: 0.0448
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 101/500 - Loss: 0.1327
# Epoch 102/500 - Loss: 0.1050
# Epoch 103/500 - Loss: 0.0868
# Epoch 104/500 - Loss: 0.1302
# Epoch 105/500 - Loss: 0.1371
# Epoch 106/500 - Loss: 2.6767
# Epoch 107/500 - Loss: 11.5751
# Epoch 108/500 - Loss: 26.4007
# Epoch 109/500 - Loss: 23.4262
# Epoch 110/500 - Loss: 18.5470
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< ir. widhy hayuhardhika nugraha, s.kom., m.kom.
# Q >>> visi filkom
# A <<< ir. widhy hayuhardhika nugraha, s.kom., m.kom.
# Q >>> misi filkom
# A <<< ir. widhy hayuhardhika nugraha, s.kom., m.kom.
# -----------------------------------------
#
# Epoch 111/500 - Loss: 18.6432
# Epoch 112/500 - Loss: 12.8494
# Epoch 113/500 - Loss: 10.1485
# Epoch 114/500 - Loss: 7.7987
# Epoch 115/500 - Loss: 6.5616
# Epoch 116/500 - Loss: 4.5917
# Epoch 117/500 - Loss: 3.6792
# Epoch 118/500 - Loss: 2.8572
# Epoch 119/500 - Loss: 2.5131
# Epoch 120/500 - Loss: 3.2055
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< agus wahyu widodo, st., m.cs.
# Q >>> visi filkom
# A <<< 1. meningkatkan kualitas dan kuantitas pengabdian masyarakat
# 2. meningkatkan pemberdayaan masyarakat
# 3. menyediakan dana, sarana dan prasarana pengabdian masyarakat
# Q >>> misi filkom
# A <<< 1. meningkatkan kualitas dan kuantitas pengabdian masyarakat
# 2. meningkatkan pemberdayaan masyarakat
# 3. menyediakan dana, sarana dan prasarana pengabdian masyarakat
# -----------------------------------------
#
# Epoch 121/500 - Loss: 3.4799
# Epoch 122/500 - Loss: 2.2404
# Epoch 123/500 - Loss: 2.3486
# Epoch 124/500 - Loss: 1.6077
# Epoch 125/500 - Loss: 0.7128
# Epoch 126/500 - Loss: 0.6286
# Epoch 127/500 - Loss: 0.6101
# Epoch 128/500 - Loss: 0.7297
# Epoch 129/500 - Loss: 0.6553
# Epoch 130/500 - Loss: 0.5956
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< drs. muh. arif rahman, m.kom.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 131/500 - Loss: 0.5141
# Epoch 132/500 - Loss: 0.4534
# Epoch 133/500 - Loss: 0.3560
# Epoch 134/500 - Loss: 0.5932
# Epoch 135/500 - Loss: 0.6166
# Epoch 136/500 - Loss: 1.0414
# Epoch 137/500 - Loss: 1.0492
# Epoch 138/500 - Loss: 2.0287
# Epoch 139/500 - Loss: 1.4843
# Epoch 140/500 - Loss: 1.8251
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 141/500 - Loss: 1.5886
# Epoch 142/500 - Loss: 0.5371
# Epoch 143/500 - Loss: 0.3631
# Epoch 144/500 - Loss: 0.4117
# Epoch 145/500 - Loss: 0.6621
# Epoch 146/500 - Loss: 0.2786
# Epoch 147/500 - Loss: 0.1550
# Epoch 148/500 - Loss: 0.1393
# Epoch 149/500 - Loss: 0.1468
# Epoch 150/500 - Loss: 0.2215
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 151/500 - Loss: 0.2961
# Epoch 152/500 - Loss: 0.1158
# Epoch 153/500 - Loss: 0.1205
# Epoch 154/500 - Loss: 0.2030
# Epoch 155/500 - Loss: 0.1483
# Epoch 156/500 - Loss: 0.1639
# Epoch 157/500 - Loss: 0.2006
# Epoch 158/500 - Loss: 0.1539
# Epoch 159/500 - Loss: 0.1520
# Epoch 160/500 - Loss: 0.1685
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 161/500 - Loss: 0.1729
# Epoch 162/500 - Loss: 0.1352
# Epoch 163/500 - Loss: 0.1089
# Epoch 164/500 - Loss: 0.1107
# Epoch 165/500 - Loss: 0.1442
# Epoch 166/500 - Loss: 0.2387
# Epoch 167/500 - Loss: 0.2582
# Epoch 168/500 - Loss: 0.1043
# Epoch 169/500 - Loss: 0.0728
# Epoch 170/500 - Loss: 0.0621
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 171/500 - Loss: 0.0582
# Epoch 172/500 - Loss: 0.0891
# Epoch 173/500 - Loss: 0.1891
# Epoch 174/500 - Loss: 0.1326
# Epoch 175/500 - Loss: 0.0702
# Epoch 176/500 - Loss: 0.0580
# Epoch 177/500 - Loss: 0.0501
# Epoch 178/500 - Loss: 0.0523
# Epoch 179/500 - Loss: 0.0740
# Epoch 180/500 - Loss: 0.1701
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 181/500 - Loss: 0.1090
# Epoch 182/500 - Loss: 0.0658
# Epoch 183/500 - Loss: 0.0533
# Epoch 184/500 - Loss: 0.0553
# Epoch 185/500 - Loss: 0.0625
# Epoch 186/500 - Loss: 0.1122
# Epoch 187/500 - Loss: 0.0829
# Epoch 188/500 - Loss: 0.0734
# Epoch 189/500 - Loss: 0.0508
# Epoch 190/500 - Loss: 0.0458
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 191/500 - Loss: 0.0444
# Epoch 192/500 - Loss: 0.0782
# Epoch 193/500 - Loss: 0.1462
# Epoch 194/500 - Loss: 0.1142
# Epoch 195/500 - Loss: 0.0639
# Epoch 196/500 - Loss: 0.0481
# Epoch 197/500 - Loss: 0.0615
# Epoch 198/500 - Loss: 0.1633
# Epoch 199/500 - Loss: 0.1277
# Epoch 200/500 - Loss: 0.3201
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelesaikan studi di bidang teknologi informasi dan ilmu komputer (ptiik)
# -----------------------------------------
#
# Epoch 201/500 - Loss: 1.7724
# Epoch 202/500 - Loss: 4.1544
# Epoch 203/500 - Loss: 4.6436
# Epoch 204/500 - Loss: 14.6785
# Epoch 205/500 - Loss: 8.7910
# Epoch 206/500 - Loss: 3.9310
# Epoch 207/500 - Loss: 2.7293
# Epoch 208/500 - Loss: 2.7967
# Epoch 209/500 - Loss: 2.2544
# Epoch 210/500 - Loss: 1.3821
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< agus wahyu widodo, st., m.cs.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 211/500 - Loss: 0.9717
# Epoch 212/500 - Loss: 1.4445
# Epoch 213/500 - Loss: 1.0654
# Epoch 214/500 - Loss: 1.3287
# Epoch 215/500 - Loss: 2.8473
# Epoch 216/500 - Loss: 3.0832
# Epoch 217/500 - Loss: 5.7295
# Epoch 218/500 - Loss: 8.3211
# Epoch 219/500 - Loss: 3.2782
# Epoch 220/500 - Loss: 3.0147
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menghasilkan lulusan yang kompeten, profesional, berbudi pekerti luhur, berjiwa entrepreneur dan berdaya saing internasional.
# menghasilkan sivitas akademika yang mampu mengembangkan penelitiandan pengabdian yang berorientasi pada pembaruan dan teknologi tepat guna untuk industri dan masyarakat.
# terwujudnya suasana akademik yang kondusif dalam bidang pendidikan, penelitian, dan pengabdian kepada masyarakat yang berdaya saing unggul.
# terwujudnya tata kelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# meningkatnya kuantitas dan kualitas kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 221/500 - Loss: 1.2598
# Epoch 222/500 - Loss: 1.3428
# Epoch 223/500 - Loss: 0.8406
# Epoch 224/500 - Loss: 1.0090
# Epoch 225/500 - Loss: 0.5596
# Epoch 226/500 - Loss: 0.2447
# Epoch 227/500 - Loss: 0.1514
# Epoch 228/500 - Loss: 0.1301
# Epoch 229/500 - Loss: 0.1113
# Epoch 230/500 - Loss: 0.1099
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 231/500 - Loss: 0.1375
# Epoch 232/500 - Loss: 0.2643
# Epoch 233/500 - Loss: 0.2788
# Epoch 234/500 - Loss: 0.1533
# Epoch 235/500 - Loss: 0.0906
# Epoch 236/500 - Loss: 0.0743
# Epoch 237/500 - Loss: 0.0665
# Epoch 238/500 - Loss: 0.0624
# Epoch 239/500 - Loss: 0.0815
# Epoch 240/500 - Loss: 0.1481
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 241/500 - Loss: 0.1309
# Epoch 242/500 - Loss: 0.0807
# Epoch 243/500 - Loss: 0.0499
# Epoch 244/500 - Loss: 0.0428
# Epoch 245/500 - Loss: 0.0387
# Epoch 246/500 - Loss: 0.0345
# Epoch 247/500 - Loss: 0.0317
# Epoch 248/500 - Loss: 0.0290
# Epoch 249/500 - Loss: 0.0270
# Epoch 250/500 - Loss: 0.0251
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 251/500 - Loss: 0.0236
# Epoch 252/500 - Loss: 0.0222
# Epoch 253/500 - Loss: 0.0211
# Epoch 254/500 - Loss: 0.0202
# Epoch 255/500 - Loss: 0.0193
# Epoch 256/500 - Loss: 0.0185
# Epoch 257/500 - Loss: 0.0178
# Epoch 258/500 - Loss: 0.0171
# Epoch 259/500 - Loss: 0.0166
# Epoch 260/500 - Loss: 0.0160
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 261/500 - Loss: 0.0155
# Epoch 262/500 - Loss: 0.0150
# Epoch 263/500 - Loss: 0.0145
# Epoch 264/500 - Loss: 0.0141
# Epoch 265/500 - Loss: 0.0137
# Epoch 266/500 - Loss: 0.0133
# Epoch 267/500 - Loss: 0.0129
# Epoch 268/500 - Loss: 0.0126
# Epoch 269/500 - Loss: 0.0122
# Epoch 270/500 - Loss: 0.0119
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 271/500 - Loss: 0.0116
# Epoch 272/500 - Loss: 0.0113
# Epoch 273/500 - Loss: 0.0110
# Epoch 274/500 - Loss: 0.0108
# Epoch 275/500 - Loss: 0.0105
# Epoch 276/500 - Loss: 0.0103
# Epoch 277/500 - Loss: 0.0100
# Epoch 278/500 - Loss: 0.0098
# Epoch 279/500 - Loss: 0.0095
# Epoch 280/500 - Loss: 0.0093
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 281/500 - Loss: 0.0091
# Epoch 282/500 - Loss: 0.0089
# Epoch 283/500 - Loss: 0.0087
# Epoch 284/500 - Loss: 0.0085
# Epoch 285/500 - Loss: 0.0083
# Epoch 286/500 - Loss: 0.0082
# Epoch 287/500 - Loss: 0.0080
# Epoch 288/500 - Loss: 0.0078
# Epoch 289/500 - Loss: 0.0076
# Epoch 290/500 - Loss: 0.0075
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 291/500 - Loss: 0.0073
# Epoch 292/500 - Loss: 0.0072
# Epoch 293/500 - Loss: 0.0070
# Epoch 294/500 - Loss: 0.0069
# Epoch 295/500 - Loss: 0.0067
# Epoch 296/500 - Loss: 0.0066
# Epoch 297/500 - Loss: 0.0065
# Epoch 298/500 - Loss: 0.0063
# Epoch 299/500 - Loss: 0.0062
# Epoch 300/500 - Loss: 0.0061
#
# -----------------------------------------
# Q >>> wakil dekan bidang akademik / wakil dekan 1
# A <<< dr. eng. ir. herman tolle, st., mt.
# Q >>> visi filkom
# A <<< menjadi fakultas yang berdaya saing internasional dan berkontribusi kepada pengembangan teknologi informasi dan ilmu komputer untuk menunjang industri dan masyarakat dengan menyelaraskan pelaksanaan pendidikan, penelitian, dan pengabdian kepada masyarakat
# Q >>> misi filkom
# A <<< menyelenggarakan pendidikan di bidang teknologi informasi dan ilmu komputer yang berkualitas dan berstandar internasional secara berkelanjutan.
# meningkatkan kemampuan sivitas akademika dalam pengembangan penelitian dan pengabdian yang selaras dengan kebutuhan industri dan masyarakat.
# mengintegrasikan pengembangan pendidikan, penelitian, dan pengabdian kepada masyarakat yang ditunjang dengan tatakelola organisasi yang transparan, akuntabel, efektif, dan efisien.
# mewujudkan kerja sama yang berkelanjutan di bidang pendidikan, penelitian, dan pengabdian kepada masyarakat dalam skala nasional dan internasional.
# -----------------------------------------
#
# Epoch 301/500 - Loss: 0.0060
# Epoch 302/500 - Loss: 0.0059
# Epoch 303/500 - Loss: 0.0057
# Epoch 304/500 - Loss: 0.0056

# %%
test_question = "fitra bachtiar punya nama lengkap teh naon"
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> fitra bachtiar punya nama lengkap teh naon
# A <<< faizatul amalia, s.pd., m.pd.

# %%
test_question = "ketua bpj"
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> ketua bpj
# A <<<  ...

# %%
test_question = "visi filkom"
outputs = model.generate(test_question)
decoded_output = model.dec_tokenizer.decode(outputs[0])
print(f'Q >>> {test_question}')
print(f'A <<< {decoded_output}')
# Out:
# Q >>> visi filkom
# A <<< dr.eng. fitra a. bachtiar

# %%
def calculate_bleu(preds, questions, answers):
    bleu_score_1 = 0
    bleu_score_2 = 0
    bleu_score_3 = 0
    bleu_score_4 = 0
    bleu_score_all = 0

    num_of_rows_calculated = 0

    for i, (question, real_answer) in enumerate(zip(questions, answers)):
        # print(f"Question: {question}")
        # print(f"Real Answer: {real_answer}")
        # print(f"Predicted Answer: {preds[i]}")
        try:
            refs = [real_answer.split(' ')]
            hyp = preds[i].split(' ')

            bleu_score_1 += sentence_bleu(refs, hyp, weights=(1,0,0,0))
            bleu_score_2 += sentence_bleu(refs, hyp, weights=(0,1,0,0))
            bleu_score_3 += sentence_bleu(refs, hyp, weights=(0,0,1,0))
            bleu_score_4 += sentence_bleu(refs, hyp, weights=(0,0,0,1))
            bleu_score_all += sentence_bleu(refs, hyp, weights=(.25,.25,.25,.25))

            num_of_rows_calculated+=1
        except:
            continue

    results = {"1-gram": (bleu_score_1/num_of_rows_calculated),
                "2-gram": (bleu_score_2/num_of_rows_calculated),
                "3-gram": (bleu_score_3/num_of_rows_calculated),
                "4-gram": (bleu_score_all/num_of_rows_calculated)}
    
    return results

# %%
all_
