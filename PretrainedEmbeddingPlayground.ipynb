# %%
# !pip install transformers
# Out:
# WARNING: Ignoring invalid distribution -aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -nsorflow-estimator (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rtifi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -gments (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -nsorflow-estimator (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rkzeug (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rtifi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -0aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -0atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -0ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -1aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -1atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -1ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -2aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -2atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -2ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3transfer (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -4aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -4atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -4ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5py (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -6aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -6atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -6ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -7aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -7atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -7ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -8atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -8ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -9atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -9ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rkzeug (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -achetools (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ackaging (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -afetensors (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andas (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andb (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -angchain (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -arkdown (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -arshmallow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -astjsonschema (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atplotlib-inline (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -azy-loader (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -bformat (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-image (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cwidth (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -dfplumber (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -dna (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -down (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -eaborn (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -edi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -egex (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -enacity (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard-data-server (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-io-gcs-filesystem (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -entry-sdk (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -equests (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -eras (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -erkzeug (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ermcolor (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ertifi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -est-asyncio (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -etproctitle (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -etuptools (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -etworkx (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ffi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -gboost (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -hapely (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -hreadpoolctl (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ifffile (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -iktoken (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ilelock (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -imm (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -iohttp (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ip (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ipenv (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -irtualenv (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -istlib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -itpython (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -itdb (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -iwisolver (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ix (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -latbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -latformdirs (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -learml (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lembic (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lick (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ltralytics (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lvmlite (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lxtend (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -maes (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mageio (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mmap (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ntlr4-python3-runtime (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -oblib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -oguru (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -okenizers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ontourpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ooch (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -oogle-auth-oauthlib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ornado (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ortalocker (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -oxr (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -penai (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -penpyxl (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ptuna (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -qdm (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -raitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rapt (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -reenlet (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -riton (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rompt-toolkit (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rozenlist (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sgpack (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sonschema (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sspec (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sttokens (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sutil (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sync-timeout (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -udioread (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -uggingface-hub (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umba (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umexpr (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -upyterlab-widgets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -xceptiongroup (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -xecuting (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -xml (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yjwt (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yyaml (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yasn1 (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yasn1-modules (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ycler (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ycparser (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yparsing (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ython (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ytz (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yzmq (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -0ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -1ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -2ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -4ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -gments (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -nsorboard-data-server (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -parsing (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -tplotlib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -width (/opt/conda/lib/python3.10/site-packages)
# Collecting transformers
#   Downloading transformers-4.42.4-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy<2.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2022.6.15)
# Downloading transformers-4.42.4-py3-none-any.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 38.1 MB/s eta 0:00:00a 0:00:01
# WARNING: Ignoring invalid distribution -aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -nsorflow-estimator (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rtifi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -gments (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -nsorflow-estimator (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rkzeug (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rtifi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -0aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -0atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -0ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -1aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -1atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -1ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -2aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -2atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -2ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3transfer (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -4aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -4atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -4ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5py (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -6aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -6atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -6ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -7aitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -7atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -7ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -8atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -8ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -9atbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -9ping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rkzeug (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -achetools (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ackaging (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -afetensors (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andas (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andb (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -angchain (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -arkdown (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -arshmallow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -astjsonschema (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atplotlib-inline (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -azy-loader (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -bformat (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-image (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -cwidth (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -dfplumber (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -dna (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -down (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -eaborn (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ebugpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -edi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -egex (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -enacity (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard-data-server (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-io-gcs-filesystem (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -entry-sdk (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -equests (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -eras (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -erkzeug (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ermcolor (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ertifi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -est-asyncio (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -etproctitle (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -etuptools (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -etworkx (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ffi (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -gboost (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -hapely (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -hreadpoolctl (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ifffile (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -iktoken (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ilelock (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -imm (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -iohttp (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ip (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ipenv (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -irtualenv (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -istlib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -itpython (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -itdb (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -iwisolver (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ix (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -latbuffers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -latformdirs (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -learml (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lembic (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lick (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ltralytics (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lvmlite (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -lxtend (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -maes (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mageio (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mmap (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ntlr4-python3-runtime (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -oblib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -oguru (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -okenizers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ontourpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ooch (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -oogle-auth-oauthlib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ornado (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ortalocker (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -oxr (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -penai (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -penpyxl (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ptuna (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -qdm (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -raitlets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rapt (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -reenlet (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -riton (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rompt-toolkit (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rozenlist (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sgpack (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sonschema (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sspec (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sttokens (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sutil (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -sync-timeout (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -udioread (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -uggingface-hub (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umba (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umexpr (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -upyterlab-widgets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -xceptiongroup (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -xecuting (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -xml (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yjwt (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yyaml (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yasn1 (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yasn1-modules (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ycler (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ycparser (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yparsing (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ython (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ytz (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yzmq (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -0ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -1ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -2ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -3ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -4ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -5ing-extensions (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -gments (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -nsorboard-data-server (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -parsing (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -tplotlib (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -width (/opt/conda/lib/python3.10/site-packages)
# Installing collected packages: transformers
# Successfully installed transformers-4.42.4

# %%
from collections import Counter
import json
import torch
import torch.nn as nn
from torch.utils.data import Dataset
import torch.utils.data
import math
import torch.nn.functional as F
import neptune
import pandas as pd

# %%
dev = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
dev
# Out:
# /home/andyalyfsyah/Environments/my_env/lib/python3.10/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11060). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# device(type='cpu')

# %%
from transformers import GPT2Tokenizer, GPT2Model, pipeline

# %%
tokenizer = GPT2Tokenizer.from_pretrained('indonesian-nlp/gpt2-medium-indonesian')
model = GPT2Model.from_pretrained('indonesian-nlp/gpt2-medium-indonesian')
text = "Ubah dengan teks apa saja."
encoded_input = tokenizer(text)

# %%
token_embedding = {token: model.get_input_embeddings()(torch.tensor(id))  for token, id in tokenizer.get_vocab().items()}
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 token_embedding = {token: model.get_input_embeddings()(torch.tensor(id))  for token, id in tokenizer.get_vocab().items()}
#
# Cell In[41], line 1, in <dictcomp>(.0)
# ----> 1 token_embedding = {token: model.get_input_embeddings()(torch.tensor(id))  for token, id in tokenizer.get_vocab().items()}
#
# File ~/Environments/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Environments/my_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Environments/my_env/lib/python3.10/site-packages/torch/nn/modules/sparse.py:163, in Embedding.forward(self, input)
#     162 def forward(self, input: Tensor) -> Tensor:
# --> 163     return F.embedding(
#     164         input, self.weight, self.padding_idx, self.max_norm,
#     165         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/Environments/my_env/lib/python3.10/site-packages/torch/nn/functional.py:2237, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2231     # Note [embedding_renorm set_grad_enabled]
#    2232     # XXX: equivalent to
#    2233     # with torch.no_grad():
#    2234     #   torch.embedding_renorm_
#    2235     # remove once script supports set_grad_enabled
#    2236     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2237 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %%
model.get_input_embeddings()
# Out:
# Embedding(50257, 1024)

# %%
print(model.get_input_embeddings()(torch.tensor(tokenizer.get_vocab()['apa'])))
# Out:
# tensor([ 0.2161, -0.0400,  0.3545,  ...,  0.1621, -0.0193,  0.1069],
#        grad_fn=<EmbeddingBackward0>)

# %%
len(features[0][0])
# Out:
# 1024

# %%
tokenizer.get_vocab()['pak']
# Out:
# 22453
