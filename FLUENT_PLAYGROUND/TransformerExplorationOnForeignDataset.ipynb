# %%
pip install nusacrowd
# Out:
# Collecting nusacrowd
#   Downloading nusacrowd-0.1.4-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.2/384.2 kB 4.4 MB/s eta 0:00:00a 0:00:01
# Collecting loguru>=0.5.3 (from nusacrowd)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 19.1 MB/s eta 0:00:00
# Collecting bioc>=1.3.7 (from nusacrowd)
#   Downloading bioc-2.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas>=1.3.3 in ./.conda/envs/myenv/lib/python3.8/site-packages (from nusacrowd) (1.5.3)
# Requirement already satisfied: numpy>=1.20 in ./.conda/envs/myenv/lib/python3.8/site-packages (from nusacrowd) (1.24.3)
# Collecting datasets>=2.2.0 (from nusacrowd)
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 8.6 MB/s eta 0:00:00a 0:00:01
# Collecting black~=22.0 (from nusacrowd)
#   Downloading black-22.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.6 MB/s eta 0:00:00a 0:00:01
# Collecting flake8>=3.8.3 (from nusacrowd)
#   Downloading flake8-7.1.0-py2.py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 25.9 MB/s eta 0:00:00
# Collecting isort>=5.0.0 (from nusacrowd)
#   Downloading isort-5.13.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 19.3 MB/s eta 0:00:00
# Collecting aiohttp>=3.8.1 (from nusacrowd)
#   Downloading aiohttp-3.9.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.7 MB/s eta 0:00:0000:01
# Collecting pre-commit>=2.19.0 (from nusacrowd)
#   Downloading pre_commit-3.5.0-py2.py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 65.6 MB/s eta 0:00:00
# Collecting jsonlines>=3.1.0 (from nusacrowd)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: torchaudio>=0.11 in ./.conda/envs/myenv/lib/python3.8/site-packages (from nusacrowd) (2.0.2)
# Collecting soundfile (from nusacrowd)
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.4 MB/s eta 0:00:00
# Collecting librosa (from nusacrowd)
#   Downloading librosa-0.10.2.post1-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.1/260.1 kB 35.5 MB/s eta 0:00:00
# Collecting nltk (from nusacrowd)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 37.4 MB/s eta 0:00:0000:01
# Collecting zstandard (from nusacrowd)
#   Downloading zstandard-0.22.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 41.1 MB/s eta 0:00:00a 0:00:01
# Collecting ffmpeg (from nusacrowd)
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting conllu (from nusacrowd)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: openpyxl in ./.conda/envs/myenv/lib/python3.8/site-packages (from nusacrowd) (3.1.3)
# Collecting translate-toolkit>=3.7.3 (from nusacrowd)
#   Downloading translate_toolkit-3.13.1-py3-none-any.whl (744 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.6/744.6 kB 56.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in ./.conda/envs/myenv/lib/python3.8/site-packages (from nusacrowd) (4.6.3)
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.8.1->nusacrowd)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.8.1->nusacrowd)
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 24.7 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.8.1->nusacrowd)
#   Downloading frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 52.9 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.8.1->nusacrowd)
#   Downloading multidict-6.0.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 43.8 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.8.1->nusacrowd)
#   Downloading yarl-1.9.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.8/308.8 kB 77.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0 (from aiohttp>=3.8.1->nusacrowd)
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting lxml>=4.6.3 (from bioc>=1.3.7->nusacrowd)
#   Downloading lxml-5.2.2-cp38-cp38-manylinux_2_28_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 51.8 MB/s eta 0:00:00a 0:00:01
# Collecting intervaltree (from bioc>=1.3.7->nusacrowd)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in ./.conda/envs/myenv/lib/python3.8/site-packages (from bioc>=1.3.7->nusacrowd) (4.65.0)
# Collecting docopt (from bioc>=1.3.7->nusacrowd)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting click>=8.0.0 (from black~=22.0->nusacrowd)
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 15.5 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.4.3 (from black~=22.0->nusacrowd)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black~=22.0->nusacrowd)
#   Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs>=2 in ./.conda/envs/myenv/lib/python3.8/site-packages (from black~=22.0->nusacrowd) (2.5.2)
# Collecting tomli>=1.1.0 (from black~=22.0->nusacrowd)
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: filelock in ./.conda/envs/myenv/lib/python3.8/site-packages (from datasets>=2.2.0->nusacrowd) (3.9.0)
# Collecting pyarrow>=15.0.0 (from datasets>=2.2.0->nusacrowd)
#   Downloading pyarrow-16.1.0-cp38-cp38-manylinux_2_28_x86_64.whl (40.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 44.0 MB/s eta 0:00:0000:0100:01
# Collecting pyarrow-hotfix (from datasets>=2.2.0->nusacrowd)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.2.0->nusacrowd)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 35.0 MB/s eta 0:00:00
# Collecting requests>=2.32.2 (from datasets>=2.2.0->nusacrowd)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 20.1 MB/s eta 0:00:00
# Collecting tqdm (from bioc>=1.3.7->nusacrowd)
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 15.8 MB/s eta 0:00:00
# Collecting xxhash (from datasets>=2.2.0->nusacrowd)
#   Downloading xxhash-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.6/194.6 kB 39.9 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.2.0->nusacrowd)
#   Downloading multiprocess-0.70.16-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in ./.conda/envs/myenv/lib/python3.8/site-packages (from datasets>=2.2.0->nusacrowd) (2023.6.0)
# Collecting huggingface-hub>=0.21.2 (from datasets>=2.2.0->nusacrowd)
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 93.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in ./.conda/envs/myenv/lib/python3.8/site-packages (from datasets>=2.2.0->nusacrowd) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.conda/envs/myenv/lib/python3.8/site-packages (from datasets>=2.2.0->nusacrowd) (6.0.1)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8>=3.8.3->nusacrowd)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting pycodestyle<2.13.0,>=2.12.0 (from flake8>=3.8.3->nusacrowd)
#   Downloading pycodestyle-2.12.0-py2.py3-none-any.whl (31 kB)
# Collecting pyflakes<3.3.0,>=3.2.0 (from flake8>=3.8.3->nusacrowd)
#   Downloading pyflakes-3.2.0-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.conda/envs/myenv/lib/python3.8/site-packages (from pandas>=1.3.3->nusacrowd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/envs/myenv/lib/python3.8/site-packages (from pandas>=1.3.3->nusacrowd) (2022.7)
# Collecting cfgv>=2.0.0 (from pre-commit>=2.19.0->nusacrowd)
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Collecting identify>=1.0.0 (from pre-commit>=2.19.0->nusacrowd)
#   Downloading identify-2.5.36-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 28.6 MB/s eta 0:00:00
# Collecting nodeenv>=0.11.1 (from pre-commit>=2.19.0->nusacrowd)
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit>=2.19.0->nusacrowd)
#   Downloading virtualenv-20.26.3-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 83.8 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: torch in ./.conda/envs/myenv/lib/python3.8/site-packages (from torchaudio>=0.11->nusacrowd) (2.0.1)
# Collecting audioread>=2.1.9 (from librosa->nusacrowd)
#   Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Collecting scipy>=1.2.0 (from librosa->nusacrowd)
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 47.7 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn>=0.20.0 (from librosa->nusacrowd)
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 56.6 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=0.14 (from librosa->nusacrowd)
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 72.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.3.0 in ./.conda/envs/myenv/lib/python3.8/site-packages (from librosa->nusacrowd) (5.1.1)
# Collecting numba>=0.51.0 (from librosa->nusacrowd)
#   Downloading numba-0.58.1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 53.4 MB/s eta 0:00:00a 0:00:01
# Collecting pooch>=1.1 (from librosa->nusacrowd)
#   Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 35.0 MB/s eta 0:00:00
# Collecting soxr>=0.3.2 (from librosa->nusacrowd)
#   Downloading soxr-0.3.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 93.1 MB/s eta 0:00:00
# Collecting lazy-loader>=0.1 (from librosa->nusacrowd)
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting msgpack>=1.0 (from librosa->nusacrowd)
#   Downloading msgpack-1.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 kB 75.3 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.0 in ./.conda/envs/myenv/lib/python3.8/site-packages (from soundfile->nusacrowd) (1.15.1)
# Collecting regex>=2021.8.3 (from nltk->nusacrowd)
#   Downloading regex-2024.5.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.2/776.2 kB 83.6 MB/s eta 0:00:00
# Requirement already satisfied: et-xmlfile in ./.conda/envs/myenv/lib/python3.8/site-packages (from openpyxl->nusacrowd) (1.1.0)
# Requirement already satisfied: pycparser in ./.conda/envs/myenv/lib/python3.8/site-packages (from cffi>=1.0->soundfile->nusacrowd) (2.21)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba>=0.51.0->librosa->nusacrowd)
#   Downloading llvmlite-0.41.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 MB 28.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: importlib-metadata in ./.conda/envs/myenv/lib/python3.8/site-packages (from numba>=0.51.0->librosa->nusacrowd) (6.0.0)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/myenv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.3.3->nusacrowd) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/envs/myenv/lib/python3.8/site-packages (from requests>=2.32.2->datasets>=2.2.0->nusacrowd) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/envs/myenv/lib/python3.8/site-packages (from requests>=2.32.2->datasets>=2.2.0->nusacrowd) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/myenv/lib/python3.8/site-packages (from requests>=2.32.2->datasets>=2.2.0->nusacrowd) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/envs/myenv/lib/python3.8/site-packages (from requests>=2.32.2->datasets>=2.2.0->nusacrowd) (2023.5.7)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.20.0->librosa->nusacrowd)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit>=2.19.0->nusacrowd)
#   Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 50.4 MB/s eta 0:00:00
# Collecting filelock (from datasets>=2.2.0->nusacrowd)
#   Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Collecting platformdirs>=2 (from black~=22.0->nusacrowd)
#   Downloading platformdirs-4.2.2-py3-none-any.whl (18 kB)
# Collecting sortedcontainers<3.0,>=2.0 (from intervaltree->bioc>=1.3.7->nusacrowd)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: sympy in ./.conda/envs/myenv/lib/python3.8/site-packages (from torch->torchaudio>=0.11->nusacrowd) (1.11.1)
# Requirement already satisfied: networkx in ./.conda/envs/myenv/lib/python3.8/site-packages (from torch->torchaudio>=0.11->nusacrowd) (2.8.4)
# Requirement already satisfied: jinja2 in ./.conda/envs/myenv/lib/python3.8/site-packages (from torch->torchaudio>=0.11->nusacrowd) (3.1.2)
# Requirement already satisfied: zipp>=0.5 in ./.conda/envs/myenv/lib/python3.8/site-packages (from importlib-metadata->numba>=0.51.0->librosa->nusacrowd) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/myenv/lib/python3.8/site-packages (from jinja2->torch->torchaudio>=0.11->nusacrowd) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in ./.conda/envs/myenv/lib/python3.8/site-packages (from sympy->torch->torchaudio>=0.11->nusacrowd) (1.2.1)
# Building wheels for collected packages: ffmpeg, docopt, intervaltree
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=3e3cf622247dc3905979f7e05dec821d8f905de7301b7cb1b3d5c753e3db1407
#   Stored in directory: /home/andyalyfsyah/.cache/pip/wheels/30/33/46/5ab7eca55b9490dddbf3441c68a29535996270ef1ce8b9b6d7
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=fd92788dd69596bd81bb4823c4e7b8ac22bcaeeff731b40f4c562fd2a22e6c84
#   Stored in directory: /home/andyalyfsyah/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26098 sha256=7f1d437878d156ba0cfe915cb3c344a9a8f00a7e2673b467b5790e06432991ef
#   Stored in directory: /home/andyalyfsyah/.cache/pip/wheels/45/23/de/5789a92962483fd33cb06674792b9697c1b3766d7c7742830e
# Successfully built ffmpeg docopt intervaltree
# Installing collected packages: sortedcontainers, ffmpeg, docopt, distlib, zstandard, xxhash, tqdm, tomli, threadpoolctl, soxr, scipy, requests, regex, pyflakes, pycodestyle, pyarrow-hotfix, pyarrow, platformdirs, pathspec, nodeenv, mypy-extensions, multidict, msgpack, mccabe, lxml, loguru, llvmlite, lazy-loader, joblib, isort, intervaltree, identify, frozenlist, filelock, dill, conllu, click, cfgv, audioread, attrs, async-timeout, yarl, virtualenv, translate-toolkit, soundfile, scikit-learn, pooch, numba, nltk, multiprocess, jsonlines, huggingface-hub, flake8, black, aiosignal, pre-commit, librosa, bioc, aiohttp, datasets, nusacrowd
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.29.0
#     Uninstalling requests-2.29.0:
#       Successfully uninstalled requests-2.29.0
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 2.5.2
#     Uninstalling platformdirs-2.5.2:
#       Successfully uninstalled platformdirs-2.5.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.9.0
#     Uninstalling filelock-3.9.0:
#       Successfully uninstalled filelock-3.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# triton 2.0.0 requires cmake, which is not installed.
# triton 2.0.0 requires lit, which is not installed.
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 async-timeout-4.0.3 attrs-23.2.0 audioread-3.0.1 bioc-2.1 black-22.12.0 cfgv-3.4.0 click-8.1.7 conllu-4.5.3 datasets-2.20.0 dill-0.3.8 distlib-0.3.8 docopt-0.6.2 ffmpeg-1.4 filelock-3.15.4 flake8-7.1.0 frozenlist-1.4.1 huggingface-hub-0.23.4 identify-2.5.36 intervaltree-3.1.0 isort-5.13.2 joblib-1.4.2 jsonlines-4.0.0 lazy-loader-0.4 librosa-0.10.2.post1 llvmlite-0.41.1 loguru-0.7.2 lxml-5.2.2 mccabe-0.7.0 msgpack-1.0.8 multidict-6.0.5 multiprocess-0.70.16 mypy-extensions-1.0.0 nltk-3.8.1 nodeenv-1.9.1 numba-0.58.1 nusacrowd-0.1.4 pathspec-0.12.1 platformdirs-4.2.2 pooch-1.8.2 pre-commit-3.5.0 pyarrow-16.1.0 pyarrow-hotfix-0.6 pycodestyle-2.12.0 pyflakes-3.2.0 regex-2024.5.15 requests-2.32.3 scikit-learn-1.3.2 scipy-1.10.1 sortedcontainers-2.4.0 soundfile-0.12.1 soxr-0.3.7 threadpoolctl-3.5.0 tomli-2.0.1 tqdm-4.66.4 translate-toolkit-3.13.1 virtualenv-20.26.3 xxhash-3.4.1 yarl-1.9.4 zstandard-0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import datasets
data = datasets.load_dataset('GEM/indonlg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import datasets
#       2 data = datasets.load_dataset('GEM/indonlg')
#
# ModuleNotFoundError: No module named 'datasets'

# %%
import nusacrowd as nc

# List all datasets
dset_names = nc.list_datasets()
dset_namesy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 import nusacrowd as nc
#       3 # List all datasets
# ----> 4 dset_names = nc.list_datasets()
#       5 dset_namesy
#
# File ~/.conda/envs/myenv/lib/python3.8/site-packages/nusacrowd/config_helper.py:958, in list_datasets(with_config)
#     957 def list_datasets(with_config=False):
# --> 958     conhelps = NusantaraConfigHelper()
#     959     return conhelps.list_datasets(with_config=with_config)
#
# File ~/.conda/envs/myenv/lib/python3.8/site-packages/nusacrowd/config_helper.py:692, in NusantaraConfigHelper.__init__(self, helpers, keep_broken)
#     688 dataset_name = dataloader_script.stem
#     689 py_module = SourceFileLoader(
#     690     dataset_name, dataloader_script.as_posix()
#     691 ).load_module()
# --> 692 ds_module = datasets.load.dataset_module_factory(
#     693     dataloader_script.as_posix()
#     694 )
#     695 ds_cls = datasets.load.import_main_class(ds_module.module_path)
#     697 for config in ds_cls.BUILDER_CONFIGS:
#
# File ~/.conda/envs/myenv/lib/python3.8/site-packages/datasets/load.py:1809, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1807 elif path.endswith(filename):
#    1808     if os.path.isfile(path):
# -> 1809         return LocalDatasetModuleFactoryWithScript(
#    1810             path,
#    1811             download_mode=download_mode,
#    1812             dynamic_modules_path=dynamic_modules_path,
#    1813             trust_remote_code=trust_remote_code,
#    1814         ).get_module()
#    1815     else:
#    1816         raise FileNotFoundError(f"Couldn't find a dataset script at {relative_to_absolute_path(path)}")
#
# File ~/.conda/envs/myenv/lib/python3.8/site-packages/datasets/load.py:975, in LocalDatasetModuleFactoryWithScript.get_module(self)
#     964         _create_importable_file(
#     965             local_path=self.path,
#     966             local_imports=local_imports,
#    (...)
#     972             download_mode=self.download_mode,
#     973         )
#     974     else:
# --> 975         raise ValueError(
#     976             f"Loading {self.name} requires you to execute the dataset script in that"
#     977             " repo on your local machine. Make sure you have read the code there to avoid malicious use, then"
#     978             " set the option `trust_remote_code=True` to remove this error."
#     979         )
#     980 module_path, hash = _load_importable_file(
#     981     dynamic_modules_path=dynamic_modules_path,
#     982     module_namespace="datasets",
#     983     subdirectory_name=hash,
#     984     name=self.name,
#     985 )
#     987 # make the new module to be noticed by the import system
#
# ValueError: Loading indolem_nerui requires you to execute the dataset script in that repo on your local machine. Make sure you have read the code there to avoid malicious use, then set the option `trust_remote_code=True` to remove this error.
